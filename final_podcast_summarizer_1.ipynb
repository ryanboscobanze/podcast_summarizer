# %%
# Required libraries for YouTube → Audio → Transcription → Summarization → UI
# !pip install fsspec==2025.3.2 requests==2.32.3 --quiet --no-warn-script-location
# !pip install git+https://github.com/openai/whisper.git --quiet
# !pip install yt-dlp pydub --quiet
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118 --quiet
# !pip install transformers datasets ipywidgets --quiet

# !ffmpeg -version || apt install ffmpeg -y


# ----------------- Device Check -----------------
import torch
from torch.cuda import get_device_name

# ----------------- Core Libraries -----------------
import os

# ----------------- Audio + Whisper -----------------
import whisper
import yt_dlp
from pydub import AudioSegment

# ----------------- Summarization -----------------
from transformers import pipeline, AutoTokenizer, AutoModelForSeq2SeqLM
from datasets import Dataset, load_from_disk

# ----------------- UI -----------------
import ipywidgets as widgets
from IPython.display import display
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 70.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 37.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 29.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 42.9 MB/s eta 0:00:00
#   Building wheel for openai-whisper (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 10.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 89.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 61.3 MB/s eta 0:00:00
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
# built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
# libavutil      56. 70.100 / 56. 70.100
# libavcodec     58.134.100 / 58.134.100
# libavformat    58. 76.100 / 58. 76.100
# libavdevice    58. 13.100 / 58. 13.100
# libavfilter     7.110.100 /  7.110.100
# libswscale      5.  9.100 /  5.  9.100
# libswresample   3.  9.100 /  3.  9.100
# libpostproc    55.  9.100 / 55.  9.100

# %% [markdown]
# ### 📥 YouTube to Summary Pipeline
#
# This code builds a pipeline that:
#
# 1. **Lists YouTube playlist videos** using `yt_dlp`.
# 2. **Downloads audio** from a selected video and converts it to MP3.
# 3. **Converts audio to WAV** (16kHz mono) for transcription.
# 4. **Transcribes speech to text** using a local Whisper model.
# 5. **Summarizes the text** using a BART-based summarizer.
#
# > Uses `yt_dlp` for YouTube handling, `pydub` for audio conversion, and Hugging Face + Whisper for transcription and summarization.

# %%
# ----------------- YouTube Playlist -----------------
def list_youtube_videos(playlist_url, max_results=10):
    """List titles and URLs of up to `max_results` videos in a YouTube playlist."""
    ydl_opts = {'extract_flat': True, 'quiet': True, 'force_generic_extractor': True}
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        info = ydl.extract_info(playlist_url, download=False)
        entries = info.get("entries", [])[:max_results]
    videos = []
    for i, video in enumerate(entries):
        title = video.get("title")
        video_id = video.get("id")
        url = f"https://www.youtube.com/watch?v={video_id}"
        print(f"{i+1}. {title}")
        videos.append((title, url))
    return videos

# ----------------- Download YouTube Audio -----------------
def download_youtube_audio(video_url, output_basename="podcast"):
    """Download best-quality audio from a YouTube video and convert to MP3."""
    for f in os.listdir():
        if f.startswith(output_basename):
            os.remove(f)
    ydl_opts = {
        'format': 'bestaudio/best',
        'outtmpl': output_basename + ".%(ext)s",
        'postprocessors': [{
            'key': 'FFmpegExtractAudio',
            'preferredcodec': 'mp3',
            'preferredquality': '192',
        }],
        'quiet': False
    }
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        ydl.download([video_url])
    for f in os.listdir():
        if f.startswith(output_basename) and f.endswith(".mp3"):
            return f
    raise FileNotFoundError("MP3 file not found after download.")

# ----------------- Return index, title, and URL from dropdown. -----------------
def get_selected_video():
    """Return the index, title, and URL of the selected video from a dropdown."""
    index, title, url = video_dropdown.value
    return index, title, url

# ----------------- Convert to WAV -----------------
def convert_to_wav(input_audio_path, output_audio_path="converted.wav"):
    """Convert input audio file to 16kHz mono WAV format (required for Whisper)."""
    audio = AudioSegment.from_file(input_audio_path)
    audio = audio.set_frame_rate(16000).set_channels(1).set_sample_width(2)
    audio.export(output_audio_path, format="wav")
    return output_audio_path

# ----------------- Transcription -----------------
def transcribe_locally(wav_path):
    """Transcribe a WAV file using the Whisper model and return the text."""
    print("🗣️ Transcribing...")
    result = whisper_model.transcribe(wav_path, verbose=True)
    return result["text"]

# ----------------- Summarize -----------------
def summarize_batch(batch):
    """Summarize a batch of text strings using the BART summarization pipeline."""
    results = summarizer_fb_bart(
        batch["text"],
        max_new_tokens=128,
        do_sample=False
    )
    return {"summary": [result['summary_text'] for result in results]}

# %% [markdown]
# ### 🧠 Load Transcription & Summarization Models
#
# 1. Checks if a CUDA GPU is available and raises an error if not.
# 2. Loads the Whisper model (base) for audio transcription.
# 3. Loads Facebook’s BART model for text summarization.
# 4. Wraps BART in a Hugging Face pipeline for easy use.
#
# > Requires GPU for faster performance and smooth processing.

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
if device != "cuda":
    raise EnvironmentError(
        "❌ No CUDA GPU found. Please go to 'Runtime > Change runtime type' and select GPU (T4 or equivalent)."
    )
# ----------------- Load Models -----------------

# 🔊 Load Whisper model for transcription (base size is a good speed/quality trade-off)
whisper_model = whisper.load_model("base", device=device)

# 📚 Load Facebook's BART model for abstractive summarization
model_name = "facebook/bart-large-cnn"

# Load tokenizer and model from Hugging Face
tokenizer_fb_bart = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name).to(device)

# Wrap the model in a pipeline for easy use
summarizer_fb_bart = pipeline("summarization", model=model, tokenizer=tokenizer_fb_bart, device=0)
# Out:
# 100%|███████████████████████████████████████| 139M/139M [00:24<00:00, 5.88MiB/s]
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Device set to use cuda:0

# %% [markdown]
# ### 📺 Load YouTube Playlist
#
# Fetches a list of video titles and URLs from the given YouTube playlist.
#
# > Uses `yt_dlp` to extract video info without downloading.

# %%
playlist_url = "https://www.youtube.com/playlist?list=PLn5MTSAqaf8peDZQ57QkJBzewJU1aUokl"
video_list = list_youtube_videos(playlist_url)
# Out:
# 1. Trump vs Powell, Solving the Debt Crisis, The $10T AGI Prize, GENIUS Act Becomes Law
# 2. Grok 4 Wows, The Bitter Lesson, Elon’s Third Party, AI Browsers, SCOTUS backs POTUS on RIFs
# 3. Big Beautiful Bill, Elon/Trump, Dollar Down Big, Harvard's Money Problems, Figma IPO
# 4. 12 Day War, Socialism Wins in NYC, Stocks All-Time High, AI Copyright, Science Corner
# 5. IPOs and SPACs are Back, Mag 7 Showdown, Zuck on Tilt, Apple's Fumble, GENIUS Act passes Senate
# 6. ICE Raids, LA Riots, Strong Economic Data, Politicized Fed, Iran War with Tucker Carlson
# 7. AI Doom vs Boom, EA Cult Returns, BBB Upside, US Steel and Golden Votes
# 8. Bond crisis looming? GOP abandons DOGE, Google disrupts Search with AI, OpenAI buys Jony Ive's IO
# 9. Trump's Big Week: Middle East Trip, China Deal, Pharma EO, "Big, Beautiful Bill" with Ben Shapiro
# 10. Fed Hesitates on Tariffs, The New Mag 7, Death of VC, Google's Value in a Post-Search World

# %% [markdown]
# ### 🎛️ Video Selection Dropdown
#
# Creates a dropdown menu to pick a video from the YouTube playlist.
#
# > Displays video titles with their index for easy selection.

# %%
# ----------------- Dropdown for Video Selection -----------------
dropdown_options = [(f"{i+1}. {title}", (i, title, url)) for i, (title, url) in enumerate(video_list)]
video_dropdown = widgets.Dropdown(
    options=dropdown_options,
    description='🎬 Pick Video:',
    style={'description_width': 'initial'},
    layout=widgets.Layout(width='100%')
)
display(video_dropdown)
# Out:
# Dropdown(description='🎬 Pick Video:', layout=Layout(width='100%'), options=(('1. Trump vs Powell, Solving the …

# %% [markdown]
# ### 🎥 Get Selected Video
#
# Retrieves the title and URL of the video chosen from the dropdown and prints the download message.

# %%
index, selected_title, selected_url = get_selected_video()
print(f"\n⏬ Downloading: {selected_title}...\n")
# Out:
# ⏬ Downloading: Trump vs Powell, Solving the Debt Crisis, The $10T AGI Prize, GENIUS Act Becomes Law...

# %% [markdown]
# ### 🎵 Download Audio
#
# Downloads the selected YouTube video's audio and saves it as an MP3 file.

# %%
mp3_file = download_youtube_audio(selected_url)
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=wu-p5xrJ8-E
# [youtube] wu-p5xrJ8-E: Downloading webpage
# [youtube] wu-p5xrJ8-E: Downloading tv client config
# [youtube] wu-p5xrJ8-E: Downloading player 27b58bb9-main
# [youtube] wu-p5xrJ8-E: Downloading tv player API JSON
# [youtube] wu-p5xrJ8-E: Downloading ios player API JSON
# [youtube] wu-p5xrJ8-E: Downloading m3u8 information
# [info] wu-p5xrJ8-E: Downloading 1 format(s): 251
# [download] Destination: podcast.webm
# [download] 100% of   67.14MiB in 00:00:00 at 146.40MiB/s
# [ExtractAudio] Destination: podcast.mp3
# Deleting original file podcast.webm (pass -k to keep)

# %% [markdown]
# ### 🔄 Convert to WAV
#
# Converts the downloaded MP3 file to 16kHz mono WAV format for transcription.

# %%
wav_file = convert_to_wav(mp3_file)

# %% [markdown]
# ### 🗣️ Transcribe Audio to Text with Whisper
#
# Uses OpenAI's Whisper `"base"` model (loaded locally) to transcribe the `.wav` audio into plain text.
#
# - The `"base"` model (~74M parameters) is selected for this prototype to balance **speed** and **resource efficiency**, especially when running on Colab T4 GPUs or limited environments.
# - It provides solid transcription quality for English and general spoken content with low latency.
#
# #### 🔁 Available Whisper Model Options
#
# | Model       | Size     | Speed       | Accuracy (English) | Notes                          |
# |-------------|----------|-------------|---------------------|--------------------------------|
# | `tiny`      | ~39M     | ⚡ Fastest   | ❌ Lowest            | Suitable for quick previews    |
# | `base`      | ~74M     | ✅ Fast      | ✅ Good              | Best for prototyping           |
# | `small`     | ~244M    | 🟡 Moderate | 🔼 Better            | Good accuracy with still-good speed |
# | `medium`    | ~769M    | 🐢 Slower   | 🟢 Very Good         | Near state-of-the-art accuracy |
# | `large-v2`  | ~1550M   | 🐌 Slowest  | ✅ Best              | Best for production / multi-language |
#
# You can swap the model by editing in transcribe_locally function:
#
# ```python
# whisper_model = whisper.load_model("small", device=device)

# %%
transcript = transcribe_locally(wav_file)
# Out:
# 🗣️ Transcribing...
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: English
# [00:00.000 --> 00:03.040]  So Gavin, were you at the cold play concert?
# [00:03.040 --> 00:04.400]  Boston last night.
# [00:05.680 --> 00:06.720]  Sadly, I missed that.
# [00:06.720 --> 00:08.480]  It's, who are you?
# [00:08.480 --> 00:09.680]  Daisy.
# [00:09.680 --> 00:10.480]  Exactly.
# [00:10.480 --> 00:13.120]  I was at home with my wife, but yeah, wow.
# [00:13.120 --> 00:13.840]  How insane.
# [00:13.840 --> 00:16.240]  There's just so many layers to that story.
# [00:16.240 --> 00:18.160]  It's impossible to get away from.
# [00:18.160 --> 00:20.080]  It'll be 72 hours of memes.
# [00:20.880 --> 00:26.720]  Dave, were you at the cold play concert in Boston last night?
# [00:26.800 --> 00:29.680]  And if so, were you with Woody, your astronaut friend?
# [00:30.320 --> 00:32.240]  Did you take Woody to the concert?
# [00:32.240 --> 00:33.440]  No counselor.
# [00:33.440 --> 00:35.920]  I was here in Santa Cruz last night.
# [00:35.920 --> 00:38.080]  Oh, you already said a cruise on a business trip.
# [00:38.960 --> 00:42.720]  The funny thing is, if they had not reacted the way they did,
# [00:42.720 --> 00:44.560]  the camera would have just peved away.
# [00:44.560 --> 00:46.000]  Yeah, nothing.
# [00:46.000 --> 00:47.040]  No one would have ever known.
# [00:47.040 --> 00:51.520]  There is some great irony to the head of people and human resources.
# [00:52.320 --> 00:54.800]  Being in an affair with the CEO apparently.
# [00:55.440 --> 00:56.000]  Allegedly.
# [00:56.000 --> 00:57.600]  Don't you own the conclusions, Jason?
# [00:57.600 --> 01:00.160]  No, he could have been cracking her back.
# [01:00.160 --> 01:01.680]  You know, like when you get the back times,
# [01:01.680 --> 01:04.640]  he could have been a chiropractic move.
# [01:04.800 --> 01:05.840]  Oh my god.
# [01:23.440 --> 01:24.640]  All right, let's get to work.
# [01:24.640 --> 01:28.400]  It is the slow, slow news weeks of summer.
# [01:28.960 --> 01:31.520]  And we are delighted, delighted.
# [01:32.000 --> 01:34.400]  Have fan favorite, super intelligent,
# [01:34.400 --> 01:37.120]  bestie, Gavin Baker with us from a treatise.
# [01:37.120 --> 01:37.760]  How are you, sir?
# [01:37.760 --> 01:38.960]  How's your summer shaping up?
# [01:40.000 --> 01:40.720]  Fantastic.
# [01:41.680 --> 01:42.640]  It's been awesome.
# [01:42.640 --> 01:43.840]  Stock market is back.
# [01:44.400 --> 01:48.320]  That's good for you because you invest in both public and private companies, yeah?
# [01:49.040 --> 01:50.080]  My firm does, yes.
# [01:50.800 --> 01:51.360]  Yeah.
# [01:51.360 --> 01:52.560]  Gavin, let me ask you a question.
# [01:52.560 --> 01:54.400]  How do you price tariffs today?
# [01:55.200 --> 01:57.040]  So where do you think this ends up?
# [01:57.040 --> 01:58.880]  Obviously, there's a lot of back and forth.
# [01:58.880 --> 02:02.080]  And you know, everyone's trying to make a read on what the end game is.
# [02:02.080 --> 02:03.840]  What's your market take?
# [02:03.840 --> 02:06.960]  Is your making investments right now and where we end up on the tariff front?
# [02:07.760 --> 02:09.120]  It is a good question.
# [02:10.000 --> 02:10.960]  It's open.
# [02:10.960 --> 02:13.520]  We're going to see what happens with sectoral tariffs.
# [02:13.520 --> 02:15.040]  I think it's hard.
# [02:15.600 --> 02:17.360]  You're doing the winning AI summit.
# [02:17.360 --> 02:19.760]  It's going to be hard to win an AI if we put um,
# [02:20.560 --> 02:21.920]  tariff-sons and meconductors.
# [02:22.640 --> 02:25.440]  But for a lot of what I do for now,
# [02:26.400 --> 02:28.960]  tariffs are not super relevant.
# [02:28.960 --> 02:32.000]  But you know, for the market, for the economy, they are relevant.
# [02:32.000 --> 02:34.400]  But for AI, there may be a little less relevant.
# [02:34.400 --> 02:38.080]  Because I think everyone is maybe a little more sophisticated
# [02:38.080 --> 02:40.240]  about the downsides of tariffs for
# [02:41.200 --> 02:43.440]  constructive data centers here in the United States.
# [02:44.720 --> 02:45.600]  And ultimately,
# [02:46.640 --> 02:48.960]  don't we look at the tariff situation and say,
# [02:49.920 --> 02:54.160]  despite the shock and awe of the opening salvo,
# [02:54.320 --> 02:57.360]  it's quite a boring position.
# [02:57.360 --> 03:02.320]  Now, it just seems to be reciprocity and reasonable reciprocity at that.
# [03:02.320 --> 03:06.160]  Yeah, that's how we would sort of categorize the end game here.
# [03:06.160 --> 03:09.120]  I would say for everyone, but China, you know, it is,
# [03:09.120 --> 03:13.200]  and we've clearly reached some sort of deal with China,
# [03:13.200 --> 03:16.880]  you know, rare earths for H20s and MI308Xs.
# [03:17.840 --> 03:18.800]  But it's interesting.
# [03:18.800 --> 03:22.960]  And one of the trade deals that has been finalized is Vietnam.
# [03:23.040 --> 03:25.600]  And there's a special carve out for goods that were
# [03:25.600 --> 03:27.680]  shipped from China through Vietnam.
# [03:28.320 --> 03:34.080]  So they are clearly focused on China more than almost in, you know, any other country,
# [03:34.080 --> 03:37.200]  rightly or wrongly. But yeah, and I do think there is,
# [03:39.520 --> 03:45.840]  you know, there was maybe three months where Trump said he did not care about the stock market.
# [03:45.840 --> 03:48.640]  But now he's back to quoting the market at all time highs.
# [03:48.640 --> 03:49.360]  Yes.
# [03:49.360 --> 03:53.280]  He clearly cares and is clearly very sensitive to market feedback.
# [03:53.280 --> 04:00.720]  So I think that that will be a dampening mechanism on tariff volatility.
# [04:02.640 --> 04:06.320]  But, you know, they pass the bill and he immediately went back to tariffs.
# [04:06.720 --> 04:08.400]  And you know, we'll see where we land in August.
# [04:09.440 --> 04:13.280]  But I just think the most important thing in the market by far is AI kind of
# [04:13.280 --> 04:14.800]  overwhelms everything else.
# [06:39.040 --> 06:44.640]  you know, how correct is it being at close to an all time low in our lifetimes.
# [06:45.280 --> 06:46.160]  Let's go macro.
# [06:46.880 --> 06:52.960]  Yeah, I wouldn't read too much into the CPI bouncing up a little bit.
# [06:52.960 --> 06:54.640]  There's base rate effects.
# [06:54.640 --> 06:57.040]  I think on a month over month basis.
# [06:57.040 --> 07:00.960]  And if you looked at what economists call core, super core,
# [07:00.960 --> 07:08.480]  different ways to maybe smooth out CPI, I think inflation is still relatively contained.
# [07:10.480 --> 07:18.960]  As far as, but I mean, a lot of very smart people are convinced that tariffs will lead to inflation.
# [07:18.960 --> 07:19.520]  We'll see.
# [07:19.520 --> 07:25.600]  There certainly sound theoretical arguments for why they will, but it does look like maybe the overseas
# [07:25.600 --> 07:30.720]  exporters are eating a little bit more of the tariffs than people thought that they would.
# [07:30.960 --> 07:32.960]  Which is good for US inflation.
# [07:32.960 --> 07:38.160]  But, you know, the combination of a very weak dollar and tariffs theoretically should lead to a little more
# [07:39.680 --> 07:40.320]  inflation.
# [07:41.360 --> 07:47.760]  Firing Powell, I worry that the market only went down 1%.
# [07:47.760 --> 07:51.600]  I do think the market would go down quite a bit more if Trump did fire Powell.
# [07:52.080 --> 07:53.120]  I think it would be a mistake.
# [07:53.840 --> 07:54.960]  I hope he doesn't do it.
# [07:55.920 --> 08:01.280]  And, you know, there are very sound reasons for the Federal Reserve to be independent.
# [08:02.320 --> 08:07.520]  And I hope he does not read from that trial balloon down 1%
# [08:08.160 --> 08:09.360]  that that's all that would happen.
# [08:09.360 --> 08:11.120]  Look, the world would continue spinning.
# [08:11.120 --> 08:14.400]  America would go on, but it would be a mistake.
# [08:16.000 --> 08:19.840]  Freeberg, we have this idea that there would be a couple of rate cuts.
# [08:19.840 --> 08:23.280]  And maybe we get monetary velocity going again.
# [08:23.280 --> 08:26.000]  People will be able to take more loans out, invest more in business.
# [08:26.000 --> 08:28.080]  But with the stock market tearing it up,
# [08:28.720 --> 08:32.320]  there's a lot of wealth being put into the system with the big beautiful bill.
# [08:32.320 --> 08:34.560]  There's a lot of spending in there as we've talked about here,
# [08:34.560 --> 08:35.680]  putting that aside.
# [08:35.680 --> 08:38.000]  It feels like the economy's in really great shape.
# [08:38.800 --> 08:40.720]  Chances of a rate cut has now flipped.
# [08:41.600 --> 08:42.480]  No changes now.
# [08:42.480 --> 08:45.280]  The favorite option for September, whereas a week ago,
# [08:45.280 --> 08:46.960]  the favorite option was 25 bits.
# [08:46.960 --> 08:50.560]  So this idea that we're going to cut or the fed's going to cut,
# [08:50.560 --> 08:52.640]  that seems to be changing as well.
# [08:52.640 --> 08:57.120]  So your thoughts on the macro picture here?
# [08:57.120 --> 09:00.880]  So I'm not sure the firing of Jerome Powell
# [09:00.880 --> 09:04.880]  necessarily solves the US fiscal challenge,
# [09:04.880 --> 09:09.920]  which is rising interest rates on the long end of the Treasury curve.
# [09:10.560 --> 09:15.600]  So if you look at the 30-year Treasury yield over time,
# [09:15.600 --> 09:17.920]  and Nick maybe you could pull this up while I'm talking,
# [09:18.000 --> 09:22.800]  but as of today, we're at exactly 5% on the 30-year.
# [09:22.800 --> 09:25.600]  And you can see that this 5% yield,
# [09:26.160 --> 09:30.080]  which is what the market is demanding the United States government pay
# [09:30.880 --> 09:36.560]  in order to be loaned the money to make the bill payments that the US government has to make every year,
# [09:37.440 --> 09:39.920]  is the highest it's been, the borrowing cost,
# [09:39.920 --> 09:43.920]  is the highest it's been since going all the way back to 2007 as of today.
# [09:44.880 --> 09:47.440]  And I think this is the real story for the United States.
# [09:47.440 --> 09:49.680]  We have $36 trillion of debt.
# [09:50.720 --> 09:55.760]  The average interest rate we're paying on that debt today is 3.3%.
# [09:55.760 --> 09:58.800]  That's the average of all the treasuries that the federal government has issued,
# [09:58.800 --> 10:04.160]  the Treasury Department has issued, to borrow the money that it is using and has used to pay all its bills.
# [10:05.200 --> 10:08.640]  And if you look at the 5% number, that's a 1.7% hike.
# [10:10.240 --> 10:14.160]  At 3.3%, which is the current average rate we're paying,
# [10:14.240 --> 10:17.840]  across $36 trillion, we have a run rate interest expense.
# [10:17.840 --> 10:23.360]  So just the money we're paying each year on the interest of the outstanding debt is $1.2 trillion a year.
# [10:24.400 --> 10:27.120]  And if this spikes up to 5% from 3.3,
# [10:27.680 --> 10:31.760]  we're talking about nearly $2 trillion a year in interest expense.
# [10:31.760 --> 10:35.200]  And that number is only going to get bigger as we borrow more money each year,
# [10:35.200 --> 10:37.040]  and the loan balance goes up.
# [10:37.040 --> 10:41.120]  The outstanding debt goes up because we are still running a deficit.
# [10:41.120 --> 10:42.960]  The government is spending more than it's making every year.
# [10:43.920 --> 10:49.520]  So the crisis that America faces is a more profound fiscal crisis,
# [10:49.520 --> 10:53.840]  where the rates that we're having to pay are a function of what the market is telling us.
# [10:53.840 --> 10:59.600]  The market does not want to loan the United States money over a 30-year period for less than 5% as of today.
# [11:00.560 --> 11:04.160]  And so making adjustments to the short end of the Treasury curve,
# [11:04.160 --> 11:07.600]  making overnight loans cheaper, which is what the Fed can do,
# [11:08.240 --> 11:12.480]  will stimulate the economy and make more money flow easily because now you'll be able to borrow
# [11:12.480 --> 11:16.800]  money overnight to do stuff like build a building, and then sell the building next week or next
# [11:16.800 --> 11:21.520]  month, or take out a car loan and pay it down and use your car to go drive for Uber and grow the
# [11:21.520 --> 11:26.800]  economy and other things. So the theory is that if we can drive rates down on the short end of
# [11:26.800 --> 11:30.560]  the curve, we'll grow the economy such that we'll be able to make those payments on the long end of
# [11:30.560 --> 11:36.480]  the curve. But there comes a point where, again, you're only going to be able to move the market
# [11:36.480 --> 11:42.400]  so much until the more important fiscal situations are going to be addressed, which is spending
# [11:43.120 --> 11:48.080]  taxation and some of the other key policy issues. So I think what the market is saying is it's not
# [11:48.080 --> 11:54.160]  as much about your own pal, and frankly, getting rid of a prudent individual may be more challenging
# [11:54.160 --> 11:57.760]  than it is beneficial when the real challenge is facing the United States need to be more
# [11:57.760 --> 12:00.880]  heartily addressed. So I think that's my kind of take on this whole topic.
# [12:00.880 --> 12:03.200]  I can't think. Yeah, go ahead, Gavin, build on it.
# [12:03.200 --> 12:07.520]  So point number one, the 30-year has gone up since pal started cutting rates.
# [12:08.400 --> 12:13.120]  So that is just empirical proof that what David is saying, I think, is right.
# [12:13.840 --> 12:20.960]  And second, the deficit has been a feature of American politics,
# [12:20.960 --> 12:29.040]  stated back to Ross Perot's 1992 presidential run. But it never ended third party run.
# [12:29.040 --> 12:34.640]  It's a third party run. Here we go. But yes, but the deficit never really mattered,
# [12:35.120 --> 12:40.560]  because interest rates kept going down, such that even has our debt grew.
# [12:41.120 --> 12:46.720]  Interest expense has kind of a percentage of the government's budget stayed relatively low.
# [12:47.360 --> 12:54.320]  Now that rates have gone up and don't seem like they're going down anytime soon,
# [12:54.320 --> 13:01.760]  the deficit does matter and it really matters. And you can kind of run a couple of scenarios,
# [13:01.760 --> 13:08.000]  but like pick your metric. If the deficit kind of continues at current levels,
# [13:08.720 --> 13:14.960]  and we were to refinance the debt at the prices that David was talking about,
# [13:16.960 --> 13:21.600]  it's only a few years before spending on interest is significantly larger than
# [13:21.600 --> 13:26.320]  spending on Medicare and Medicaid, our social security, our the military. So pick something
# [13:26.320 --> 13:33.360]  you care about, but our current course in speed, it's in the not too distant future where
# [13:33.360 --> 13:38.720]  interest expense is the biggest line item for the government. And that is not healthy. And that's
# [13:38.720 --> 13:44.480]  why the deficit finally matters is just that rates are higher. But the great thing is, as there is
# [13:44.480 --> 13:51.280]  a virtuous cycle here, as you close the deficit, rates should theoretically come down.
# [13:51.760 --> 13:58.400]  And then those both feed on each other to kind of help the problem. And it is possible.
# [13:58.400 --> 14:05.280]  There's no silver bullet here, but some combination of slowing government spending, extra revenue,
# [14:05.280 --> 14:10.720]  and tariffs are effectively, we've never had a consumption tax here in America,
# [14:11.680 --> 14:14.800]  which I think is a good thing because consumption taxes are very regressive.
# [14:14.960 --> 14:21.520]  But the reality is, like even when Obama controlled the House, the Senate, and was the most
# [14:21.520 --> 14:26.720]  popular Democratic president of our lifetime, I don't think federal government tax receipts
# [14:26.720 --> 14:31.520]  has a percentage of GDP got above 18, 19%. So that's kind of the ceiling.
# [14:33.200 --> 14:39.360]  And it for income taxes alone. And tariffs are really just a consumption tax that kind of
# [14:39.360 --> 14:44.080]  incensed domestic manufacturing. I mean, there's all sorts of reasons. They're bad ideas.
# [14:44.800 --> 14:50.320]  David Ricardo, the theory of comparative advantage, 100% correct. Free trade is a good thing.
# [14:52.080 --> 14:57.440]  But introducing some sort of a consumption tax, growing the economy a little bit faster through
# [14:57.440 --> 15:03.600]  deregulation, and slowing government spending, I think there is a way out of this for America.
# [15:04.400 --> 15:08.640]  But it's important to find the way because the deficit finally does matter. After
# [15:08.640 --> 15:13.600]  really never mattering in my political lifetime. It is interesting. We've never had to worry about
# [15:13.600 --> 15:18.800]  our debt. It was always manageable because it wasn't that large. And even when it got large,
# [15:18.800 --> 15:23.360]  it wasn't compared to GDP because the country was doing so well. We had the PC revolution.
# [15:23.360 --> 15:27.440]  We had the internet boom. I mean, we've had boom after boom after boom in efficiency that we've
# [15:27.440 --> 15:32.400]  led the world. And these companies like Google or Apple take over the world and all those tax
# [15:32.400 --> 15:38.320]  receipts and income comes into our country. That does sort of make you not look at it. I guess
# [15:38.320 --> 15:43.440]  I haven't talked to you, Gavin, and not to make this super political. But both parties have proven
# [15:43.440 --> 15:49.120]  that they have no interest historically and in the current one with cutting spending. It's just
# [15:49.120 --> 15:53.680]  the nature of it. So we can sit here, whether you're a Biden-Fantrum fan, put it all aside.
# [15:54.400 --> 15:59.920]  Both parties love spending and they're not stopping. One of our friends has proposed, hey, maybe in
# [15:59.920 --> 16:05.360]  the midterms, we have a couple of these house positions, a couple of senators, maybe we try to
# [16:05.360 --> 16:09.600]  flip them and create a new party that cares about this issue. What are your thoughts, probably,
# [16:09.600 --> 16:16.480]  on that? A couple of more Joe Manchin types were in the House, the Senate. Could this country
# [16:17.200 --> 16:24.480]  maybe start to make this the deciding issue? And maybe could we see some movement on the other
# [16:24.480 --> 16:28.720]  two parties, some pressure on them by a third party, an America party, perhaps?
# [16:29.680 --> 16:36.080]  Yeah, well, I think a few things. I do think there is room for a much more centrist party in America.
# [16:37.520 --> 16:46.400]  You know, the way the primaries work, it leads to more maybe extreme candidates than anyone would
# [16:46.400 --> 16:52.800]  actually want, you know, being each party's candidate. So I think a third party would be helpful.
# [16:53.760 --> 16:59.200]  You know, and I think there's plenty of room for a party that is, you know, kind of a
# [17:00.400 --> 17:08.800]  fiscally conservative, reasonably socially liberal, pro-American energy production,
# [17:10.320 --> 17:14.480]  all kinds of energy production, including solar, importantly.
# [17:16.640 --> 17:20.720]  So I think there's room for that and I think it is right that if you just target a few races,
# [17:20.720 --> 17:25.200]  you can have a big impact. But I would just say, yeah, well, humbly, I think the American party is
# [17:25.200 --> 17:32.640]  a great idea. I just don't know that it is the highest and best use of Elon's talents at this moment
# [17:32.640 --> 17:41.200]  in time with what's happening with AI. And just, you know, to the extent Elon is a friend of the pod,
# [17:41.200 --> 17:49.200]  I just think staying focused AI Mars, that might be the highest and best use of his particular talents.
# [17:49.200 --> 17:54.800]  100% hasn't that been the case for some time, Gavin, and anytime there's something, whether it's
# [17:54.800 --> 18:00.480]  neural link or boring company or some other new project that there's these claims that this is
# [18:00.480 --> 18:07.680]  a distraction away from the highest priority work that should be done. I mean, it's a political
# [18:07.680 --> 18:11.600]  stuff unique. And then his point is you and the political stuff, just like it was with Twitter,
# [18:12.240 --> 18:17.040]  is that it's existential to society and civilization and our ability to function and to do,
# [18:17.360 --> 18:23.200]  you know, to achieve the progress that he aims to achieve in his core function. So obviously he is
# [18:23.200 --> 18:31.440]  succeeding being the CEO of many different companies. But, you know, I think a big part of what makes him
# [18:31.440 --> 18:38.640]  kind of exceptional has a CEO is the perfectionism, the drive, and you know, politics is not a game
# [18:38.640 --> 18:45.280]  of perfection. It's a game of compromise. So I am sure if he sets his mind to the America party,
# [18:45.280 --> 18:50.880]  that he will succeed, but I think there are other things for him to focus on. And, you know,
# [18:50.880 --> 18:56.400]  the boring company and your link, these are games of perfection. These are, you know, this is about
# [18:56.400 --> 19:02.400]  engineering, this is about solving a problem. It's not, you know, compromise in the art of the possible.
# [19:02.880 --> 19:10.880]  So I think he would succeed. I just think that there are other things that maybe a higher calling
# [19:10.880 --> 19:17.440]  for him. Yeah. Yeah. I mean, and the cost of being away from his businesses this last time around,
# [19:18.160 --> 19:24.800]  as he said very publicly was severe. It was intense and he's had to really regroup, but we got this
# [19:24.800 --> 19:29.200]  incredible news when Grog four came out. And I think we should maybe talk a little bit here about
# [19:29.200 --> 19:35.440]  what that big prize is. The big prize, big is most, well, it's actually a good, you know, a question
# [19:35.520 --> 19:40.160]  freeberg. I think the big prize is whoever wins general intelligence, super intelligence,
# [19:40.160 --> 19:45.680]  or the biggest cluster, or the most power to power the biggest cluster, that power is general,
# [19:45.680 --> 19:53.200]  super intelligent. So where do we sit on the language models today, Gavin and Elon's recent,
# [19:55.200 --> 20:01.280]  let's just call it what it is. I mean, incredibly dominant release of Grog four. I don't think
# [20:01.280 --> 20:05.920]  people expected that. They didn't expect him to be able to leapfrog everybody. And let's be
# [20:05.920 --> 20:11.840]  honest, people are leapfrogging each other every four to six months. So I fully expect Gemini will
# [20:11.840 --> 20:16.720]  leapfrog rock and opening high will have their time in the sun again as well. But this was pretty
# [20:16.720 --> 20:21.840]  impressive, right? I'll say this is the biggest leapfrog we've seen in quite some time. And I think
# [20:21.840 --> 20:30.400]  the benchmarks that matter are RKGI to and humanity's last exam where it did in the case of RKGI to
# [20:30.400 --> 20:34.880]  it's called semi-private, which is important because it means that some of the questions were
# [20:34.880 --> 20:41.440]  held back because the criticism of these models is they memorized the answer. And so RKGI to it has
# [20:41.440 --> 20:47.360]  not seen the questions before. And it did roughly twice as good as, you know, the state of our Google
# [20:48.480 --> 20:54.560]  OpenAI and Anthropic models. And then our humanity's last exam, you know, we can call it 50 to 75%
# [20:55.360 --> 21:00.720]  that are, you know, an exceptional human score 5% on that. It scores in the 40s.
# [21:02.800 --> 21:08.320]  So this is incredible progress. And I think it's worth mentioning this model was trained on
# [21:08.320 --> 21:14.640]  Hopper. So this model is probably about as far as you can take the last generation of Nvidia GPUs.
# [21:15.360 --> 21:21.200]  The next models we see, you know, GROC5, you know, 05 from OpenAI, whatever they're going to call
# [21:21.440 --> 21:26.720]  the next Gemini, they will be trained on Blackwell. And I think that will be a really big step
# [21:26.720 --> 21:32.880]  function. But I do think the ultimate price here is artificial superintelligence. Like I think
# [21:32.880 --> 21:38.960]  artificial general intelligence will create a lot of economic value. But, you know, and, you know,
# [21:38.960 --> 21:43.840]  maybe we will be able to work classes humans. But I think ASI artificial superintelligence is what
# [21:43.840 --> 21:48.320]  is really exciting, you know, in terms of maybe, you know, being able to live longer, you know,
# [21:48.320 --> 21:52.800]  really kind of fundamentally kind of change the fabric of our lives. Can you take a stab at
# [21:52.800 --> 21:57.680]  explaining that difference in definition to the audience who they hear these terms? And we kind
# [21:57.680 --> 22:05.200]  of bundle them into either a transcendent intelligence that we haven't seen before that we as humans
# [22:05.200 --> 22:10.640]  can't comprehend. It goes beyond human intelligence. Or this is the smartest human on the planet. And
# [22:10.640 --> 22:15.200]  where we are right now in this journey. Because I think these terms are all getting muddled together.
# [22:15.200 --> 22:17.760]  And I think we have an interesting conversation here if we parse them.
# [22:18.400 --> 22:25.760]  I think artificial general intelligence, I would define it as an AI that can take economically
# [22:25.760 --> 22:32.080]  useful actions in a variety of domains and be better than the average human in most domains,
# [22:32.080 --> 22:38.160]  all domains. But that's very different than superintelligence. You know, being, you know,
# [22:38.160 --> 22:42.480]  being able to draft a contract, that's not superintelligence, but it is useful being able to do a
# [22:42.480 --> 22:46.720]  medical diagnosis. It's not superintelligence, but it is useful. You know, being able to book my
# [22:46.720 --> 22:53.840]  travel, so on and so forth. Superintelligence means exactly what you said that it is smarter than
# [22:53.840 --> 22:59.280]  any human. But it has, you know, access to all of human knowledge. And I think one of the most
# [22:59.280 --> 23:04.800]  interesting questions is what will the economic returns to superintelligence be? And they're
# [23:04.800 --> 23:10.000]  definitely unknowable because we have never seen superintelligence before. If is humans,
# [23:10.720 --> 23:17.120]  we have kind of pushed the limits of physics, biology, chemistry, the laws of the universe,
# [23:17.760 --> 23:22.960]  then maybe the economic returns to superintelligence won't be that high. But if superintelligence is
# [23:22.960 --> 23:27.600]  cheering cancer and inventing warp drives, then the returns are going to be really, really high.
# [23:27.600 --> 23:32.960]  And it's fundamentally unknowable. Yeah. Okay. So we're at general intelligence.
# [23:32.960 --> 23:37.360]  Hey, you're lawyer, you're tax or account that's going to go much faster. They'll have a cold
# [23:37.360 --> 23:42.240]  pilot. This is all going to be great for a business. Every business gets 10% more efficient
# [23:42.240 --> 23:47.520]  a month. Seems like a reasonable bogey, which means every seven, eight, nine months,
# [23:47.520 --> 23:51.760]  every business is going to get twice as efficient at these kind of chores. Yeah.
# [23:52.560 --> 23:56.720]  I think that I wouldn't say that's a reasonable bogey. I think that might be a little aggressive.
# [23:56.720 --> 24:02.560]  It's, you know, the world, the world always, it's, you know, I think it's a, a Bill Gates quote,
# [24:03.440 --> 24:07.840]  the world always changes less than you expect over the next one, two, three years,
# [24:07.840 --> 24:13.040]  but way more than you expect over 10 years. Just takes time for technologies to diffuse.
# [24:13.040 --> 24:17.600]  You may be really nimble startups. We'll see some of the gains that you're talking about.
# [24:18.160 --> 24:23.040]  But I mean, if we doubled productivity, I mean, that would be like an economic revolution.
# [24:23.600 --> 24:29.440]  I mean, we're seeing it in programming. I for sure talk to the average developer. They, I think,
# [24:29.440 --> 24:33.600]  would say they're getting five to 10% better a month better being defined as faster,
# [24:33.600 --> 24:40.640]  shipping more code. Rule of 72. Hey, you know, every year, at least you're going to be twice as good.
# [24:40.640 --> 24:44.880]  I think that actually seems to be happening with developers. I think it is happening with software.
# [24:44.880 --> 24:50.800]  I think software is the first area where you've seen a real true kind of economic productivity impact
# [24:52.240 --> 24:56.720]  generalized. A lot of companies are having incredible success with AI for customers, you know,
# [24:56.720 --> 25:01.840]  support for sales. I think you see it more in startups and big companies, but the impact it has had
# [25:01.840 --> 25:07.440]  on coding is undeniable. Fribert, let me swing this around to you. We've got the super intelligence
# [25:07.440 --> 25:13.920]  out there. We've got AGI out there. One of the things Gavin said was, by definition, you can't
# [25:13.920 --> 25:20.240]  quantify the gains of super intelligence. That is the big price here. That's why people are putting
# [25:20.240 --> 25:25.280]  this much money into these kind of data centers. Yeah, in your mind, it's not just the general
# [25:25.280 --> 25:30.240]  intelligence. That would be the silver medal. People are going for the gold here, not general
# [25:30.240 --> 25:34.720]  intelligence, super intelligence, breakthroughs that we can imagine. Am I, would you say that's a
# [25:34.720 --> 25:45.040]  fair way to sum up the massive interest in investing in these projects? Yeah, I mean, I think there's
# [25:45.040 --> 25:54.560]  something where everyone has identified this asymptotic return moment where if you get to that
# [25:54.560 --> 26:01.680]  moment, you're limitless in terms of the upside. Is there one winner? I don't know. I don't think so.
# [26:02.640 --> 26:07.920]  But I would also kind of reframe this as being some binary condition that I think we're talking
# [26:07.920 --> 26:14.640]  about it as being quote general intelligence, super intelligence as being on a spectrum of leverage
# [26:15.200 --> 26:22.800]  towards complexity. Complexity meaning like I can do a simple task. Like instead of writing a
# [26:23.520 --> 26:31.280]  letter and putting it in a non-volope and having some guy carry it to my mom, you know, and she gets
# [26:31.280 --> 26:36.800]  the next day, I can digitally get her that message instantly over email. That creates an incredible
# [26:36.800 --> 26:41.280]  amount of leverage and solves a lot of the complexity of getting her that communication from me.
# [26:41.280 --> 26:47.920]  So if I as a human said, I would like to harness fusion power similar to what the sun uses to make
# [26:47.920 --> 26:55.360]  energy. And I want to do that on earth. Today we're in your 40 or 50 of a research cycle of humans
# [26:55.360 --> 26:59.680]  trying to solve that particularly complex problem. It's a scientific problem, it's a discovery
# [26:59.680 --> 27:05.680]  problem, it's an engineering problem. And this idea of super intelligence is that it could give us
# [27:05.680 --> 27:12.960]  immense leverage in solving that complex problem that we otherwise maybe challenge to solve over
# [27:12.960 --> 27:18.400]  decades or hundreds of years or think about one day solving a problem that would take humans
# [27:18.400 --> 27:23.280]  thousands of years to solve. I don't think that humans are limited in our ability to solve problems.
# [27:23.280 --> 27:30.800]  I think we're limited in terms of time and what intelligence, what digital intelligence gives us is
# [27:30.800 --> 27:37.040]  leverage on time so that we can now tackle ever more complex tasks that as you think about these tasks,
# [27:37.040 --> 27:40.640]  the amount of time isn't just an incremental one year or two years but it becomes 100 years or maybe
# [27:40.640 --> 27:48.160]  a thousand years. So this relates to I think projects around physics, around chemistry, around
# [27:48.160 --> 27:55.040]  transportation, around biology where we're probably fundamentally scratching the surface today
# [27:56.000 --> 28:01.040]  and where the super intelligence is an enormous leverage crater for us. And so I don't view it as
# [28:01.040 --> 28:08.080]  some like species or race that independently persists in its own intentions but it is a tool that
# [28:08.080 --> 28:13.520]  provides leverage in a way that is orders of magnitude greater than the leverage we got from
# [28:13.520 --> 28:17.760]  yesterday or digital tools and probably today's AI tools and probably tomorrow's
# [28:18.720 --> 28:24.080]  general intelligence tools is kind of how I would think about it. And you know maybe it's because
# [28:24.080 --> 28:28.480]  one model does so much stuff better than any human you can call it super intelligence but I think
# [28:28.480 --> 28:34.240]  functionally leverage into complexity is where this becomes super compelling for humans and it's
# [28:34.240 --> 28:40.960]  why I think we can and should be highly optimistic about living very long lives and traveling anywhere
# [28:40.960 --> 28:46.000]  we want and having abundance in food and having abundance in resources and having abundance in
# [28:46.000 --> 28:50.800]  recouping our time to do the things we want to do instead of the things that we have to do today
# [28:50.800 --> 28:55.440]  because we don't have access to this incredible leverage. So that's where I get kind of
# [28:55.440 --> 29:00.160]  kind of I think it's a great way to look at it but I want to go back to the silver metal here in
# [29:00.160 --> 29:06.320]  this sort of competition. Gold being super intelligence we start solving fusion and really big problems
# [29:06.320 --> 29:10.560]  on deep research cycles and the velocity of that goes up but just going back to the silver
# [29:11.520 --> 29:16.880]  everybody in the economy becomes I don't know single digit, it's more efficient every month
# [29:17.520 --> 29:23.040]  and you know some amount every year. I've been trying to back of the envelope what I think the value
# [29:23.040 --> 29:33.120]  is for a human being in the west in the modern world and what they should spend on AI per month.
# [29:33.120 --> 29:40.160]  I've come up with a number of about 75 150 bucks somewhere in that range is a no brainer to spend
# [29:40.160 --> 29:47.040]  on your AI per month as an individual working in the world. If that's the premise right I think
# [29:47.040 --> 29:52.720]  there's a billion people in the developed world who could spend let's call it a hundred a month,
# [29:52.720 --> 29:58.000]  it's 1200 a year doesn't take a genius to figure out this is a trillion dollars in revenue
# [29:58.880 --> 30:04.320]  based on market cap that's probably ten trillion dollars in market cap and then we just have to
# [30:04.320 --> 30:08.960]  back into the spending of what it costs to build this you're doing these kind of calculations I'm sure
# [30:08.960 --> 30:15.200]  to treat is yeah and we're this general back of the envelope that I've come up with in my mind for
# [30:15.200 --> 30:19.440]  a mental model that there's a ten trillion dollar prize a trillion dollars in revenue just in
# [30:19.440 --> 30:25.440]  the silver medal does that jive with the spending we're seeing today I think people are putting in
# [30:25.440 --> 30:29.840]  ten billion dollars worth of equipment a year it across five different companies right.
# [30:30.800 --> 30:35.200]  Well I think they're putting in quite a bit more than 10 billion per year. I'm each.
# [30:36.160 --> 30:40.400]  No no each go alone doing 70 billion this year each of 70.
# [30:40.960 --> 30:45.040]  Yeah is that 70 billion they're putting in this year are going to be repeated for the next five
# [30:45.040 --> 30:51.120]  years so it'll be 350 billion if you look at if you well yeah tpd the future is always uncertain
# [30:51.120 --> 30:56.320]  yeah but you know if there are economic returns to that they will keep doing it for sure or something
# [30:56.320 --> 31:02.640]  interesting is yeah AI is you know as we discussed in previous all-ins extremely compute intensive
# [31:03.360 --> 31:08.400]  and it's just at no point in my career as a tech investor except the very beginning which was
# [31:08.400 --> 31:13.680]  kind of the end of the PC wars which Dell won by being a low cost producer going direct cutting out
# [31:13.680 --> 31:19.120]  the working capital you know the components in a PC depreciates so if you have to go through a store
# [31:20.320 --> 31:25.120]  where it sits on the shelves you're at a big disadvantage from you know either a you know call it a
# [31:25.120 --> 31:30.000]  cost or quality perspective but at no point in the 25 years I've been a tech investor as being the
# [31:30.000 --> 31:35.920]  low cost producer mattered being the low cost producers really going to matter in AI because
# [31:36.640 --> 31:42.640]  at some level the amount of tokens you produce is intelligence because of test time compute
# [31:43.360 --> 31:48.080]  you know post-training reinforcement learning and so if you can produce those tokens at a lower cost
# [31:48.080 --> 31:53.840]  you'll have a big advantage you know if for that 75 billion or 30 billion or 50 billion that
# [31:53.840 --> 32:01.200]  you're spending per year and cap X you can produce more tokens that is a profound advantage I don't
# [32:01.280 --> 32:10.560]  like your calculations like just has a back of the envelope you know kind of scratch they seem
# [32:10.560 --> 32:16.640]  reasonable to me the trillion dollars a year in revenue because of AI seems quite reasonable when
# [32:16.640 --> 32:23.440]  you frame it as a thousand dollars for a person to be whatever 30 40 50 percent more efficient at
# [32:23.440 --> 32:27.680]  work every year yeah and it's just you we could probably go back and look at kind of like the
# [32:27.680 --> 32:32.800]  early days of you know cell phones and what were people willing to pay relative to disposable
# [32:32.800 --> 32:38.240]  income your PC analogy would actually be the perfect one a PC at back in the air that error was
# [32:38.240 --> 32:42.720]  what three four thousand dollars per person they lasted for three years so it was exactly a thousand
# [32:42.720 --> 32:50.960]  a year but this is why this is why creating such delineated distinction between different types of AI
# [32:50.960 --> 32:58.880]  I think is is also like the equivalent of trying to create distinctions between other types of
# [32:58.880 --> 33:07.520]  technology so the the automobile the airplane the telephone the computer all of these technologies
# [33:07.520 --> 33:12.560]  are tools that created leverage leverage on things that were otherwise complexity and reduce them
# [33:12.560 --> 33:18.000]  down to simplicity from a human perspective pick up the phone make a call instead of getting up
# [33:18.000 --> 33:23.760]  on your horse and going across the country to deliver a message or using a computer to do a
# [33:23.760 --> 33:29.280]  spreadsheet that calculated everything for you rather than calculated by hand and so on and so
# [33:29.280 --> 33:35.440]  forth like all of these tools reduce complexity to simple tasks for humans and the ever increasing
# [33:35.440 --> 33:41.200]  complexity of what we can accomplish with digital tools is you know continuing in this kind of
# [33:41.200 --> 33:46.480]  era now but that's why I think it's very similar Jason like we this is not some new concept it's
# [33:46.480 --> 33:50.000]  it's the continuation of human productivity it's the continuation of the improvement
# [33:50.640 --> 33:54.720]  of what humans can do and what we can produce what we can and yes there's a concept now that
# [33:54.720 --> 34:00.240]  intelligence has become such a like it's caught up to everything and Gavin I don't know if you
# [34:00.240 --> 34:04.800]  think that there is this concept of some moment of singularity but it does feel to me like there's
# [34:04.800 --> 34:10.720]  just extraordinary leverage it's being created that's for similar to yeah for sure that's true I hope
# [34:10.720 --> 34:17.200]  that's true I hope your vision of it being a productivity enhancer for humans is correct you know I
# [34:17.200 --> 34:24.720]  do think you know people deep in AI do think there's some probability that it goes sideways but I hope
# [34:24.720 --> 34:30.320]  I hope that you're right but coming back to to Jake house you know $10 trillion prize and you know
# [34:30.320 --> 34:35.200]  relative to you know the market caps of the companies involved and it needs to be at least $10
# [34:35.360 --> 34:41.440]  trillion something that I think is is interesting and and relevant particularly to crock for being
# [34:41.440 --> 34:49.760]  the best product is the best product doesn't always win in technology no and yeah in sports you
# [34:49.760 --> 34:55.840]  know they say defense wins championships and on the internet distribution wins championships
# [34:55.840 --> 35:03.840]  and crock four has formidable competitors with lots of distribution and Google and meta meta if
# [35:03.840 --> 35:09.600]  think of their software Microsoft and so from an industrial logic perspective something that I
# [35:09.600 --> 35:16.000]  think makes a lot of sense particularly since open AI but Johnny ives hardware startup which will
# [35:16.000 --> 35:22.240]  place them into a competition with Apple at some point is X AI and Apple are natural partners there's
# [35:22.240 --> 35:27.360]  been a lot of news about Apple thinking about buying perplexity or mixed raw but that's just a
# [35:27.360 --> 35:33.360]  band-aid those companies don't get Apple what they need and apples had an incredible partnership for
# [35:33.360 --> 35:37.680]  many years now with Google that's generating tens of billions of dollars for both companies
# [35:38.240 --> 35:44.560]  and I think there is solid industrial logic for partnership you could have Apple crock safe
# [35:44.560 --> 35:49.840]  crock whatever you want to call it you know so that Apple feels comfortable and that probably also
# [35:49.840 --> 35:55.600]  helps crock in the enterprise and then it also helps both Apple and Google with this DOJ trial
# [35:56.240 --> 36:02.720]  and so I think in this you know an incredibly high elo chess match that is being played
# [36:03.360 --> 36:11.440]  between the leading labs like that is that partnership makes a lot of sense for both companies.
# [36:11.440 --> 36:14.640]  The first time I've heard anybody sort of make that natural connection but you're right
# [36:15.280 --> 36:22.080]  Eric Schmidt and Steve Jobs at one point had this discussion which was hey we've got search and
# [36:22.080 --> 36:26.080]  you've got a browser now because the iPhone didn't have a browser you know
# [36:27.040 --> 36:30.320]  you know they could have built their own search engine they could have partnered with Yahoo but they
# [36:30.320 --> 36:35.040]  decided to make this long-term partnership with Google and man that dropped what 20 30 billion to
# [36:35.040 --> 36:42.080]  the bottom line at Apple and cemented Google search franchise. Absolutely and right now that deal
# [36:42.800 --> 36:50.240]  is being litigated by the DOJ and the DOJ is considering remedies and so if you bring on a really
# [36:50.240 --> 36:57.200]  kind of effective credible AI provider I think you could help both Google and Apple with their
# [36:57.200 --> 37:03.200]  antitrust issues and at the end of the day you know Google they have Android and their Pixel phones
# [37:03.200 --> 37:12.960]  open AI's making hardware anthropic is kind of a captive of Amazon meta is kind of a you know
# [37:12.960 --> 37:18.640]  they're in a deathmatch with Apple so I think there is really sound logic for that partnership
# [37:18.640 --> 37:22.960]  I think it would be good for both companies love to see it happen. It feels to me like the
# [37:22.960 --> 37:27.600]  interface is going to be the browser I know this sounds crazy but I've been playing with the
# [37:27.600 --> 37:32.800]  comment browser from complexity did you play with it yet Gavin or look at some of the demos yeah
# [37:34.080 --> 37:39.920]  and what are your thoughts here because it's really and then Chatchy PT just launched a virtual
# [37:40.720 --> 37:46.320]  desktop that pops up to go do who you're you know little web-based
# ...
# [01:08:42.320 --> 01:08:47.920]  and she she did not like losing there's there's a fundamental reason for this David because
# [01:08:48.000 --> 01:08:53.040]  Elizabeth Warren and her crowd want to see a central bank digital currency what they want is
# [01:19:05.360 --> 01:19:08.000]  like sexual tension but we just need to release that out
# [01:19:23.440 --> 01:19:25.440]  i'm going on

# %% [markdown]
# ### 📄 Chunk and Prepare Transcript
#
# 1. Splits the transcript into overlapping text chunks.
# 2. Stores the chunks in a Hugging Face `Dataset` for batch summarization.
#
# > Overlap ensures context is preserved between chunks.

# %%
# ----------------- Chunking and Summarizing with Dataset -----------------
overlap = 100
chunk_size = 1024
chunks = [transcript[i:i+chunk_size] for i in range(0, len(transcript), chunk_size - overlap)]

# Create dataset
# prompts = [f"Summarize this podcast segment:\n{chunk}" for chunk in chunks]
dataset = Dataset.from_dict({"text": chunks})

print(f"Processing {len(chunks)} chunks using dataset approach...")
# Out:
# Processing 86 chunks using dataset approach...

# %%
dataset[0]
# Out:
# {'text': " So Gavin, were you at the cold play concert? Boston last night. Sadly, I missed that. It's, who are you? Daisy. Exactly. I was at home with my wife, but yeah, wow. How insane. There's just so many layers to that story. It's impossible to get away from. It'll be 72 hours of memes. Dave, were you at the cold play concert in Boston last night? And if so, were you with Woody, your astronaut friend? Did you take Woody to the concert? No counselor. I was here in Santa Cruz last night. Oh, you already said a cruise on a business trip. The funny thing is, if they had not reacted the way they did, the camera would have just peved away. Yeah, nothing. No one would have ever known. There is some great irony to the head of people and human resources. Being in an affair with the CEO apparently. Allegedly. Don't you own the conclusions, Jason? No, he could have been cracking her back. You know, like when you get the back times, he could have been a chiropractic move. Oh my god. All right, let's get to work. It is the slow"}

# %% [markdown]
# ### 🧠 Summarize in Batches
#
# Runs summarization on transcript chunks in batches using the Hugging Face dataset.
#
# > Improves speed and efficiency for large transcripts.

# %%
# 📦 Process the dataset in batches for summarization
processed_dataset = dataset.map(
    summarize_batch,
    batched=True,
    batch_size=8,
    desc="🔄 Summarizing chunks"
)
# Out:
# 🔄 Summarizing chunks:   0%|          | 0/86 [00:00<?, ? examples/s]
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset

# %% [markdown]
# ### 📝 Build Final Summary
#
# Joins all chunk summaries into one final summary and prints a short preview.
#
# > Creates a clean, readable summary from the full transcript.

# %%
# 🧠 Combine chunk summaries into final output (no part labels)
summaries = processed_dataset["summary"]
final_summary = "\n\n".join(s.strip() for s in summaries)

# 📤 Display result
print(f"📝 Final summary length: {len(final_summary)} characters")
print(final_summary[:100])  # Preview the first 100 characters
# Out:
# 📝 Final summary length: 27714 characters
# Gavin: "There's just so many layers to that story. It's impossible to get away from" Gavin: "If they

# %% [markdown]
# ### 💾 Save Summary with Pickle
#
# Saves the final summary and video title to a `.pkl` file for later use.
#
# > Uses Python's `pickle` to store multiple objects together.

# %%
import pickle

# Save objects
with open("/content/podcast_summary.pkl", "wb") as f:
    pickle.dump((final_summary, selected_title), f)

print("✅ Saved to podcast_summary.pkl")
# Out:
# ✅ Saved to podcast_summary.pkl

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# final_summary, selected_title

# %%
dataset.save_to_disk("podcast_summarizer_dataset")
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/87 [00:00<?, ? examples/s]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/podcast_summary.pkl /content/drive/MyDrive/podcast_summary.pkl
