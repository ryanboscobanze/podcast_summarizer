# %%
# Required libraries for YouTube → Audio → Transcription → Summarization → UI
# !pip install fsspec requests --quiet --no-warn-script-location

# %%
# !pip install git+https://github.com/openai/whisper.git --quiet
# !pip install yt-dlp pydub --quiet
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118 --quiet
# !pip install transformers datasets ipywidgets --quiet

# !ffmpeg -version || apt install ffmpeg -y
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 112.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 50.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 38.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 10.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 29.3 MB/s eta 0:00:00
#   Building wheel for openai-whisper (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 66.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 30.8 MB/s eta 0:00:00
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
# built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
# libavutil      56. 70.100 / 56. 70.100
# libavcodec     58.134.100 / 58.134.100
# libavformat    58. 76.100 / 58. 76.100
# libavdevice    58. 13.100 / 58. 13.100
# libavfilter     7.110.100 /  7.110.100
# libswscale      5.  9.100 /  5.  9.100
# libswresample   3.  9.100 /  3.  9.100
# libpostproc    55.  9.100 / 55.  9.100

# %%
# ----------------- Device Check -----------------
import torch
from torch.cuda import get_device_name

# ----------------- Core Libraries -----------------
import os

# ----------------- Audio + Whisper -----------------
import whisper
import yt_dlp
from pydub import AudioSegment

# ----------------- Summarization -----------------
from transformers import pipeline, AutoTokenizer, AutoModelForSeq2SeqLM
from datasets import Dataset, load_from_disk

# ----------------- UI -----------------
import ipywidgets as widgets
from IPython.display import display

# %% [markdown]
# ### 📥 YouTube to Summary Pipeline
#
# This code builds a pipeline that:
#
# 1. **Lists YouTube playlist videos** using `yt_dlp`.
# 2. **Downloads audio** from a selected video and converts it to MP3.
# 3. **Converts audio to WAV** (16kHz mono) for transcription.
# 4. **Transcribes speech to text** using a local Whisper model.
# 5. **Summarizes the text** using a BART-based summarizer.
#
# > Uses `yt_dlp` for YouTube handling, `pydub` for audio conversion, and Hugging Face + Whisper for transcription and summarization.

# %%
# ----------------- YouTube Playlist -----------------
def list_youtube_videos(playlist_url, max_results=10):
    """List titles and URLs of up to `max_results` videos in a YouTube playlist."""
    ydl_opts = {'extract_flat': True, 'quiet': True, 'force_generic_extractor': True}
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        info = ydl.extract_info(playlist_url, download=False)
        entries = info.get("entries", [])[:max_results]
    videos = []
    for i, video in enumerate(entries):
        title = video.get("title")
        video_id = video.get("id")
        url = f"https://www.youtube.com/watch?v={video_id}"
        print(f"{i+1}. {title}")
        videos.append((title, url))
    return videos

# ----------------- Download YouTube Audio -----------------
def download_youtube_audio(video_url, output_basename="podcast"):
    """Download best-quality audio from a YouTube video and convert to MP3."""
    for f in os.listdir():
        if f.startswith(output_basename):
            os.remove(f)
    ydl_opts = {
        'format': 'bestaudio/best',
        'outtmpl': output_basename + ".%(ext)s",
        'postprocessors': [{
            'key': 'FFmpegExtractAudio',
            'preferredcodec': 'mp3',
            'preferredquality': '192',
        }],
        'quiet': False
    }
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        ydl.download([video_url])
    for f in os.listdir():
        if f.startswith(output_basename) and f.endswith(".mp3"):
            return f
    raise FileNotFoundError("MP3 file not found after download.")

# ----------------- Return index, title, and URL from dropdown. -----------------
def get_selected_video():
    """Return the index, title, and URL of the selected video from a dropdown."""
    index, title, url = video_dropdown.value
    return index, title, url

# ----------------- Convert to WAV -----------------
def convert_to_wav(input_audio_path, output_audio_path="converted.wav"):
    """Convert input audio file to 16kHz mono WAV format (required for Whisper)."""
    audio = AudioSegment.from_file(input_audio_path)
    audio = audio.set_frame_rate(16000).set_channels(1).set_sample_width(2)
    audio.export(output_audio_path, format="wav")
    return output_audio_path

# ----------------- Transcription -----------------
def transcribe_locally(wav_path):
    """Transcribe a WAV file using the Whisper model and return the text."""
    print("🗣️ Transcribing...")
    result = whisper_model.transcribe(wav_path, verbose=True)
    return result["text"]

# ----------------- Summarize -----------------
def summarize_batch(batch):
    """Summarize a batch of text strings using the BART summarization pipeline."""
    results = summarizer_fb_bart(
        batch["text"],
        max_new_tokens=128,
        do_sample=False
    )
    return {"summary": [result['summary_text'] for result in results]}

# %% [markdown]
# ### 🧠 Load Transcription & Summarization Models
#
# 1. Checks if a CUDA GPU is available and raises an error if not.
# 2. Loads the Whisper model (base) for audio transcription.
# 3. Loads Facebook’s BART model for text summarization.
# 4. Wraps BART in a Hugging Face pipeline for easy use.
#
# > Requires GPU for faster performance and smooth processing.

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
if device != "cuda":
    raise EnvironmentError(
        "❌ No CUDA GPU found. Please go to 'Runtime > Change runtime type' and select GPU (T4 or equivalent)."
    )
# ----------------- Load Models -----------------

# 🔊 Load Whisper model for transcription (base size is a good speed/quality trade-off)
whisper_model = whisper.load_model("base", device=device)

# 📚 Load Facebook's BART model for abstractive summarization
model_name = "facebook/bart-large-cnn"

# Load tokenizer and model from Hugging Face
tokenizer_fb_bart = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name).to(device)

# Wrap the model in a pipeline for easy use
summarizer_fb_bart = pipeline("summarization", model=model, tokenizer=tokenizer_fb_bart, device=0)
# Out:
# 100%|███████████████████████████████████████| 139M/139M [00:01<00:00, 79.7MiB/s]
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Device set to use cuda:0

# %% [markdown]
# ### 📺 Load YouTube Playlist
#
# Fetches a list of video titles and URLs from the given YouTube playlist.
#
# > Uses `yt_dlp` to extract video info without downloading.

# %%
playlist_url = "https://www.youtube.com/playlist?list=PLn5MTSAqaf8peDZQ57QkJBzewJU1aUokl"
video_list = list_youtube_videos(playlist_url)
# Out:
# 1. Trump vs Powell, Solving the Debt Crisis, The $10T AGI Prize, GENIUS Act Becomes Law
# 2. Grok 4 Wows, The Bitter Lesson, Elon’s Third Party, AI Browsers, SCOTUS backs POTUS on RIFs
# 3. Big Beautiful Bill, Elon/Trump, Dollar Down Big, Harvard's Money Problems, Figma IPO
# 4. 12 Day War, Socialism Wins in NYC, Stocks All-Time High, AI Copyright, Science Corner
# 5. IPOs and SPACs are Back, Mag 7 Showdown, Zuck on Tilt, Apple's Fumble, GENIUS Act passes Senate
# 6. ICE Raids, LA Riots, Strong Economic Data, Politicized Fed, Iran War with Tucker Carlson
# 7. AI Doom vs Boom, EA Cult Returns, BBB Upside, US Steel and Golden Votes
# 8. Bond crisis looming? GOP abandons DOGE, Google disrupts Search with AI, OpenAI buys Jony Ive's IO
# 9. Trump's Big Week: Middle East Trip, China Deal, Pharma EO, "Big, Beautiful Bill" with Ben Shapiro
# 10. Fed Hesitates on Tariffs, The New Mag 7, Death of VC, Google's Value in a Post-Search World

# %% [markdown]
# ### 🎛️ Video Selection Dropdown
#
# Creates a dropdown menu to pick a video from the YouTube playlist.
#
# > Displays video titles with their index for easy selection.

# %%
# ----------------- Dropdown for Video Selection -----------------
dropdown_options = [(f"{i+1}. {title}", (i, title, url)) for i, (title, url) in enumerate(video_list)]
video_dropdown = widgets.Dropdown(
    options=dropdown_options,
    description='🎬 Pick Video:',
    style={'description_width': 'initial'},
    layout=widgets.Layout(width='100%')
)
display(video_dropdown)
# Out:
# Dropdown(description='🎬 Pick Video:', layout=Layout(width='100%'), options=(('1. Trump vs Powell, Solving the …

# %% [markdown]
# ### 🎥 Get Selected Video
#
# Retrieves the title and URL of the video chosen from the dropdown and prints the download message.

# %%
index, selected_title, selected_url = get_selected_video()
print(f"\n⏬ Downloading: {selected_title}...\n")
# Out:
# ⏬ Downloading: 12 Day War, Socialism Wins in NYC, Stocks All-Time High, AI Copyright, Science Corner...

# %% [markdown]
# ### 🎵 Download Audio
#
# Downloads the selected YouTube video's audio and saves it as an MP3 file.

# %%
mp3_file = download_youtube_audio(selected_url)
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Dp75wqOrtBs
# [youtube] Dp75wqOrtBs: Downloading webpage
# [youtube] Dp75wqOrtBs: Downloading tv client config
# [youtube] Dp75wqOrtBs: Downloading player 27b58bb9-main
# [youtube] Dp75wqOrtBs: Downloading tv player API JSON
# [youtube] Dp75wqOrtBs: Downloading ios player API JSON
# [youtube] Dp75wqOrtBs: Downloading m3u8 information
# [info] Dp75wqOrtBs: Downloading 1 format(s): 251
# [download] Destination: podcast.webm
# [download] 100% of   95.43MiB in 00:00:04 at 21.62MiB/s
# [ExtractAudio] Destination: podcast.mp3
# Deleting original file podcast.webm (pass -k to keep)

# %% [markdown]
# ### 🔄 Convert to WAV
#
# Converts the downloaded MP3 file to 16kHz mono WAV format for transcription.

# %%
wav_file = convert_to_wav(mp3_file)

# %% [markdown]
# ### 🗣️ Transcribe Audio to Text with Whisper
#
# Uses OpenAI's Whisper `"base"` model (loaded locally) to transcribe the `.wav` audio into plain text.
#
# - The `"base"` model (~74M parameters) is selected for this prototype to balance **speed** and **resource efficiency**, especially when running on Colab T4 GPUs or limited environments.
# - It provides solid transcription quality for English and general spoken content with low latency.
#
# #### 🔁 Available Whisper Model Options
#
# | Model       | Size     | Speed       | Accuracy (English) | Notes                          |
# |-------------|----------|-------------|---------------------|--------------------------------|
# | `tiny`      | ~39M     | ⚡ Fastest   | ❌ Lowest            | Suitable for quick previews    |
# | `base`      | ~74M     | ✅ Fast      | ✅ Good              | Best for prototyping           |
# | `small`     | ~244M    | 🟡 Moderate | 🔼 Better            | Good accuracy with still-good speed |
# | `medium`    | ~769M    | 🐢 Slower   | 🟢 Very Good         | Near state-of-the-art accuracy |
# | `large-v2`  | ~1550M   | 🐌 Slowest  | ✅ Best              | Best for production / multi-language |
#
# You can swap the model by editing in transcribe_locally function contingent on infrastructure availability:
#
# ```python
# whisper_model = whisper.load_model("small", device=device)

# %%
transcript = transcribe_locally(wav_file)
# Out:
# 🗣️ Transcribing...
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: English
# [00:00.000 --> 00:02.640]  Did you guys see this white house video?
# [00:02.640 --> 00:04.480]  Oh, is your white house video?
# [00:04.480 --> 00:09.840]  I honestly think that was the funniest post by a white house ever.
# [00:09.840 --> 00:11.840]  It was the daddy's home video.
# [00:11.840 --> 00:13.840]  Oh.
# [00:13.840 --> 00:17.120]  I feel like poppin' bottles to this.
# [00:17.120 --> 00:18.120]  Come on now.
# [00:18.120 --> 00:19.720]  Up in the club.
# [00:19.720 --> 00:21.680]  Oh, in the VIP.
# [00:21.680 --> 00:22.920]  Poppin' bottles.
# [00:22.920 --> 00:28.560]  With the rainmen, let's buy two bottles of that call in tequila.
# [00:28.560 --> 00:31.520]  That's what I got a double.
# [00:31.520 --> 00:32.520]  That is the best.
# [00:32.520 --> 00:36.560]  The backstory of that is that Mark Ruto is the secretary general of NATO, called Trump Daddy
# [00:36.560 --> 00:37.560]  at the summit.
# [00:37.560 --> 00:39.560]  Yeah, he called him daddy.
# [00:39.560 --> 00:41.360]  Oh, okay, got weird.
# [00:41.360 --> 00:42.360]  Rainbow, I missed it.
# [00:42.360 --> 00:43.720]  We were just up in the club.
# [00:43.720 --> 00:45.200]  You want to go back to the club for a second?
# [00:45.200 --> 00:46.200]  I do.
# [00:46.200 --> 00:47.200]  I love the club.
# [00:47.200 --> 00:48.200]  You ready?
# [00:48.200 --> 00:49.200]  I love the club.
# [00:49.200 --> 00:50.200]  Poppin' some bottles with the NATO summit.
# [00:50.200 --> 00:51.200]  We're doing it again.
# [00:51.200 --> 00:52.200]  Come on, freeberg.
# [00:52.200 --> 00:54.200]  Let me see you stand up, freeberg.
# [00:55.200 --> 01:00.240]  You're soaked enough science.
# [01:00.240 --> 01:02.040]  What club are we going to this weekend?
# [01:02.040 --> 01:03.880]  Oh, Daddy's home.
# [01:03.880 --> 01:05.880]  We are going to bring the club to us.
# [01:05.880 --> 01:07.120]  I think it's called Club NATO.
# [01:07.120 --> 01:08.120]  Sax, can you get the hot pass?
# [01:08.120 --> 01:09.960]  You want to come to Vegas this weekend?
# [01:09.960 --> 01:10.960]  Maybe.
# [01:10.960 --> 01:11.960]  I don't know.
# [01:11.960 --> 01:12.960]  Oh, man.
# [01:12.960 --> 01:14.960]  Oh, oh, oh, oh, oh.
# [01:14.960 --> 01:15.960]  Chik-Hell, come out.
# [01:15.960 --> 01:16.960]  Where are you?
# [01:16.960 --> 01:17.960]  Poppin' a Southwest flight.
# [01:17.960 --> 01:18.960]  Me, this is Vegas.
# [01:19.240 --> 01:21.720]  That's what I'm doing.
# [01:21.720 --> 01:23.520]  Oh, man.
# [01:23.520 --> 01:26.480]  Oh, you're winter's ride.
# [01:26.480 --> 01:33.880]  Rainman, David Sack, and I said we open source it to the fans, and they've just got
# [01:33.880 --> 01:34.880]  a lot of racing with them.
# [01:34.880 --> 01:35.880]  Love you guys, nice.
# [01:35.880 --> 01:38.800]  We know, kid, why I'm going to leave.
# [01:38.800 --> 01:39.800]  All right, everybody.
# [01:39.800 --> 01:45.040]  Welcome back to the number one podcast in the world, the all-in podcast, your favorite
# [01:45.040 --> 01:46.040]  podcast.
# [01:46.040 --> 01:48.880]  We're back with the original quartet here.
# [01:48.880 --> 01:54.280]  And everybody's really excited because we had a fun time on Saturday night.
# [01:54.280 --> 01:57.120]  What a party we had at Delilah.
# [01:57.120 --> 01:58.120]  All four besties.
# [01:58.120 --> 02:00.720]  They are step-and-repeat.
# [02:00.720 --> 02:06.480]  Freiburg, you lost a bunch of money playing bomb pods with me in Rob Goldberg, you drank
# [02:06.480 --> 02:08.960]  a lot, you looked great.
# [02:08.960 --> 02:12.200]  Your impressions of this evening.
# [02:12.200 --> 02:14.000]  Oh, I love this.
# [02:14.000 --> 02:15.000]  It was great.
# [02:15.000 --> 02:16.720]  I think that's Kila turned out fantastic.
# [02:16.720 --> 02:21.240]  Just to Kila has been, I mean, you guys realize when we first started talking about this,
# [02:21.240 --> 02:26.080]  this was like two and a half, almost three years ago, when we first started talking about
# [02:26.080 --> 02:27.080]  this.
# [02:27.080 --> 02:29.120]  And it is finally here.
# [02:29.120 --> 02:34.240]  It took forever to get through this kind of design development process.
# [02:34.240 --> 02:35.560]  But man, I think it turned out great.
# [02:35.560 --> 02:36.560]  I thought it was awesome.
# [02:36.560 --> 02:41.240]  Everybody at the party was surprised by how good it was because they thought that, I
# [02:41.240 --> 02:45.040]  don't know, we were just doing this as a gimmick or something, but we actually put it in
# [02:45.040 --> 02:46.040]  the time to make it great.
# [02:46.160 --> 02:47.040]  A lot of time.
# [02:47.040 --> 02:48.040]  A lot of time.
# [02:48.040 --> 02:54.640]  So, talk a little bit about the sourcing because I think that sourcing was very important.
# [02:54.640 --> 02:56.960]  Well we went down to Kila, Mexico.
# [02:56.960 --> 03:01.640]  There's only one part of Mexico that's even allowed to be called Kila.
# [03:01.640 --> 03:09.200]  And we found a distillery that had been aging some agave in American oak whiskey barrels
# [03:09.200 --> 03:11.040]  for five years.
# [03:11.040 --> 03:13.880]  And normally extra on Yejo is eight for three years.
# [03:13.880 --> 03:19.120]  So it was pretty rare to find a cache of five year age.
# [03:19.120 --> 03:20.400]  And so we basically bought it all.
# [03:20.400 --> 03:22.280]  But there's only enough for 7,500 bottles.
# [03:22.280 --> 03:23.760]  So that's what we did.
# [03:23.760 --> 03:29.160]  But this is not about creating some large new Kila label.
# [03:29.160 --> 03:32.600]  This is more about creating something that we ourselves like.
# [03:32.600 --> 03:33.600]  And that's what we did.
# [03:33.600 --> 03:34.600]  Sort of a small batch product.
# [03:34.600 --> 03:39.000]  I mean, the money's not going to change anyone's life, except maybe yours.
# [03:39.000 --> 03:40.000]  Yeah.
# [03:40.000 --> 03:41.000]  That's a little bit.
# [03:41.000 --> 03:42.000]  I don't know.
# [03:42.000 --> 03:43.280]  I'm getting another record today.
# [03:43.280 --> 03:46.480]  So over past 88, you guys are all.
# [03:46.480 --> 03:48.080]  I don't have to be here anymore.
# [03:48.080 --> 03:49.080]  Oh my God.
# [03:49.080 --> 03:50.560]  But look, we do things because they're fun.
# [03:50.560 --> 03:52.280]  And it was fun to create this here.
# [03:52.280 --> 03:53.280]  I've got the.
# [03:53.280 --> 03:54.280]  It is fun.
# [03:54.280 --> 03:55.280]  It was really fun.
# [03:55.280 --> 03:56.280]  Well, look at this thing.
# [03:56.280 --> 03:59.160]  I mean, beautiful box slides open.
# [03:59.160 --> 04:01.480]  It's backlit in the box.
# [04:01.480 --> 04:02.480]  So good.
# [04:02.480 --> 04:03.880]  That out of the box experience is just amazing.
# [04:03.880 --> 04:05.680]  Yeah, it's a great unboxing.
# [04:05.680 --> 04:06.760]  Steve Jobs would be proud.
# [04:06.760 --> 04:09.000]  Tell us about the bottle design.
# [04:09.000 --> 04:10.480]  That was a lot of works.
# [04:10.600 --> 04:13.920]  I think this probably took an extra six months to get this right.
# [04:13.920 --> 04:19.080]  If I'm if I'm required correctly on the schedule, this is super complicated to execute.
# [04:19.080 --> 04:22.560]  Well, the bottle is designed after a stack of poker chips.
# [04:22.560 --> 04:25.200]  And so you can see the chips are stacked and there are a jar.
# [04:25.200 --> 04:28.160]  So it's like highly it's a lot of texture here.
# [04:28.160 --> 04:29.160]  It's made with glass.
# [04:29.160 --> 04:35.320]  And then there's these black chip accents that are actually painted onto the bottle perfectly.
# [04:35.320 --> 04:37.760]  So this took a lot to get right.
# [04:37.760 --> 04:42.360]  And then we went through a lot of prototypes to get this and it just looks amazing.
# [04:42.360 --> 04:43.360]  All right.
# [04:43.360 --> 04:44.360]  There you have it.
# [04:44.360 --> 04:48.560]  Folks, the all in tequila has promised it's finally available on our website.
# [04:48.560 --> 04:52.840]  So if you go to tequila dot all in dot com, you can now buy it.
# [04:52.840 --> 04:54.440]  There's only 7500 bottles.
# [04:54.440 --> 04:58.840]  I think we're only going to sell 6,000 because we're going to keep the rest for our personal
# [04:58.840 --> 04:59.840]  status.
# [04:59.840 --> 05:00.840]  We sold a good chunk already.
# [05:00.840 --> 05:02.240]  Like I think we're so they're going really fast.
# [05:02.240 --> 05:04.200]  We just opened up the website.
# [05:04.200 --> 05:07.560]  Previously, they were only available to people who had attended the all in summit.
# [05:07.560 --> 05:09.480]  They could pre-order it and reserve.
# [05:09.480 --> 05:10.880]  But now the website is open.
# [05:10.880 --> 05:11.880]  Oh, wow.
# [05:11.880 --> 05:12.880]  Beautiful.
# [05:12.880 --> 05:13.880]  It is.
# [05:13.880 --> 05:14.880]  Okay.
# [05:14.880 --> 05:15.880]  There you go.
# [05:15.880 --> 05:17.200]  What are your bottle limit to two?
# [05:17.200 --> 05:18.200]  And go ahead.
# [05:18.200 --> 05:20.440]  So this is, you know, this is not a cheap product.
# [05:20.440 --> 05:25.440]  But you know, if you look at the, the pure competitor for this product is the Clause's
# [05:25.440 --> 05:29.920]  Ultra, which I think sells at $1,700 a bottle.
# [05:29.920 --> 05:32.480]  Although sometimes I've seen itself as much as 3,000 a bottle.
# [05:32.480 --> 05:34.400]  So we're price competitively with that.
# [05:34.400 --> 05:35.400]  There you go.
# [05:35.400 --> 05:40.080]  You have those boxes and when you open it up, the lights up and you can recharge it.
# [05:40.080 --> 05:41.080]  So it's a keepsake, right?
# [05:41.080 --> 05:46.040]  There's a charging port in the box so that it never runs out of the battery to power
# [05:46.040 --> 05:47.040]  the light.
# [05:47.040 --> 05:48.040]  So genius.
# [05:48.040 --> 05:49.040]  So genius.
# [05:49.040 --> 05:50.040]  I love that little touch.
# [05:50.040 --> 05:51.040]  All right, folks.
# [05:51.040 --> 05:53.040]  There's tons in the new, look at this.
# [05:53.040 --> 05:54.040]  I'm sorry.
# [05:54.040 --> 05:58.880]  I mean, before we get to World War Three, let's get to Room, sir.
# [05:58.880 --> 05:59.880]  I said the ****.
# [05:59.880 --> 06:00.880]  Beep that out.
# [06:00.960 --> 06:04.840]  Samantha, do you want a side of caviar with your besties all in tequila?
# [06:06.040 --> 06:08.560]  Listen, being an elitist, guys, is very hard.
# [06:08.560 --> 06:10.240]  That's what I was tweeting how stressful it is.
# [06:10.240 --> 06:14.920]  Somebody was saying that we weren't living up to our job as being the elite.
# [06:14.920 --> 06:15.920]  Huh.
# [06:15.920 --> 06:18.400]  And I was like, man, this is, it's really stressful being an elite.
# [06:18.400 --> 06:20.120]  You know, we need, we need a drink.
# [06:20.120 --> 06:21.120]  Absolutely.
# [06:21.120 --> 06:22.120]  I'll take a double.
# [06:22.120 --> 06:23.120]  You have no idea.
# [06:23.120 --> 06:25.720]  So did you go with, what, what were on your eggs, Bernays?
# [06:25.720 --> 06:27.760]  There did you go with the truffles or the caviar?
# [06:27.760 --> 06:28.760]  What did you do?
# [06:28.920 --> 06:32.720]  I, you know, I want to say, I, I went quite healthy.
# [06:32.720 --> 06:34.720]  I have some avocado.
# [06:34.720 --> 06:35.720]  Okay, Bernays.
# [06:35.720 --> 06:37.720]  I have mango.
# [06:37.720 --> 06:39.720]  And I have some eggs.
# [06:39.720 --> 06:41.720]  We're up to $72.
# [06:41.720 --> 06:42.720]  Okay.
# [06:42.720 --> 06:45.720]  David, do you want to see my pillows with my initials on them?
# [06:45.720 --> 06:46.720]  Yeah.
# [06:46.720 --> 06:47.720]  Oh, Lord, here we go.
# [06:47.720 --> 06:50.000]  This is the best thing that the **** does.
# [06:50.000 --> 06:52.000]  Shout out to our friends at Polita Goat.
# [06:52.000 --> 06:54.000]  How out of touch we are.
# [06:54.000 --> 06:55.000]  Look, Sachs.
# [06:55.000 --> 06:56.000]  They always put my initials.
# [06:56.000 --> 06:57.000]  Oh, they do that for you.
# [06:57.000 --> 06:58.000]  They do that for me.
# [06:58.560 --> 06:59.760]  Isn't that incredible?
# [06:59.760 --> 07:00.760]  Okay.
# [07:00.760 --> 07:01.760]  Here we go.
# [07:01.760 --> 07:02.760]  All right.
# [07:02.760 --> 07:04.200]  There's lots of discuss in the news.
# [07:04.200 --> 07:10.240]  We'll shift from conspicuous consumption and talk about the 12-day war between Israel
# [07:10.240 --> 07:11.240]  and Iran.
# [07:11.240 --> 07:12.600]  It's two weeks later.
# [07:12.600 --> 07:18.440]  Obviously, a quick recap here and then we'll get the besties take on where we're at today.
# [07:18.440 --> 07:19.840]  June 26th when we taped this.
# [07:19.840 --> 07:22.960]  Friday, June 13th, Israel launched a surprise attack.
# [07:23.080 --> 07:29.240]  Took out a bunch of Iranian military officials, some folks who work on the nuclear program
# [07:29.240 --> 07:34.520]  and they traded missiles for about a week before everybody debating if this was going
# [07:34.520 --> 07:36.280]  to be World War III and on Saturday.
# [07:36.280 --> 07:37.600]  June 21st, quite shocking.
# [07:37.600 --> 07:41.760]  The US jumped in and carried out operation midnight hammer.
# [07:41.760 --> 07:45.160]  I've had a couple of weekends in Vegas that have been called midnight hammer.
# [07:45.160 --> 07:46.160]  Oh, yes.
# [07:46.160 --> 07:47.160]  Midnight hammer.
# [07:47.160 --> 07:48.160]  Also known.
# [07:48.160 --> 07:49.160]  Wow.
# [07:49.160 --> 07:51.000]  There we go, folks.
# [07:51.400 --> 07:57.760]  Over a dozen bunker buster bombs on two, maybe three of Iran's key nuclear facilities,
# [07:57.760 --> 07:59.160]  Fort O and Natanz.
# [07:59.160 --> 08:00.560]  These bombs weigh 15 tons each.
# [08:00.560 --> 08:02.840]  They'll go deep underground.
# [08:02.840 --> 08:06.760]  Israel doesn't have them and that's the reason we're given of why we were pulled into
# [08:06.760 --> 08:10.600]  this is because we're the only people in the world who could have taken these out.
# [08:10.600 --> 08:16.880]  On Thursday morning, Chairman of the Joint Chiefs of Staff, Dan Cain showed a video.
# [08:16.880 --> 08:18.920]  If you haven't seen the folks, just came out this morning.
# [08:18.920 --> 08:19.920]  Here's the video.
# [08:20.320 --> 08:24.440]  It's a video of what they call a massive ordinance penetrator.
# [08:24.440 --> 08:26.920]  It basically goes through the ground.
# [08:26.920 --> 08:31.520]  I think in this case is going through a ventilation shaft and it doesn't immediately go off.
# [08:31.520 --> 08:35.160]  It basically borrows to its maximum depth and then goes off.
# [08:35.160 --> 08:36.640]  This looks like a test to me.
# [08:36.640 --> 08:37.760]  This is just demonstrating it.
# [08:37.760 --> 08:38.760]  This is a demonstration.
# [08:38.760 --> 08:39.760]  This is a demonstration.
# [08:39.760 --> 08:40.760]  Yes.
# [08:40.760 --> 08:44.280]  And so here's the before and after photos you've probably seen kind of hard to understand
# [08:44.280 --> 08:46.440]  what's going on here except for the discolourization.
# [08:46.440 --> 08:49.720]  Obviously we're going for things underground.
# [08:49.720 --> 08:56.880]  Then shockingly, Iran did a, I don't know what you call this, a ceremonial response,
# [08:56.880 --> 09:00.040]  sacs where they sent some missiles to one of our bases in Qatar.
# [09:00.040 --> 09:01.680]  They gave us a ton of notice.
# [09:01.680 --> 09:03.640]  None of them landed.
# [09:03.640 --> 09:09.120]  And then both countries have been bombing each other a little bit after Trump said he negotiated
# [09:09.120 --> 09:14.040]  a ceasefire which made our president a little bit upset.
# [09:14.040 --> 09:19.680]  Here's the clip of the president not dropping a moab, but dropping an F-bomb.
# [09:19.680 --> 09:23.680]  Israel as soon as we made the deal, they came out and they dropped the load of bombs
# [09:23.680 --> 09:26.040]  the likes of which I've never seen before.
# [09:26.040 --> 09:27.800]  The biggest load that we've seen.
# [09:27.800 --> 09:29.640]  I'm not happy with Israel.
# [09:29.640 --> 09:34.320]  You know, when I say, okay, now you have 12 hours, you don't go out in the first hour
# [09:34.320 --> 09:36.160]  and just drop everything you have on them.
# [09:36.160 --> 09:37.800]  So I'm not happy with them.
# [09:37.800 --> 09:39.440]  I'm not happy with Iran either.
# [09:39.440 --> 09:45.240]  We basically have two countries that have been fighting so long and so hard that they don't
# [09:45.240 --> 09:46.840]  know what the fuck they're doing.
# [09:46.840 --> 09:47.840]  Do you understand that?
# [09:48.840 --> 09:49.840]  What?
# [09:49.840 --> 09:51.440]  Trump is not happy.
# [09:51.440 --> 09:52.440]  He did the lean in.
# [09:52.440 --> 09:55.040]  You notice the lean in their sacks when he dropped the F-bomb?
# [09:55.040 --> 10:01.480]  Well, in fairness, President Trump's not the first president to drop an F-bomb in frustration
# [10:01.480 --> 10:03.760]  with Netanyahu.
# [10:03.760 --> 10:09.640]  It was reported back in the 90s that Bill Clinton, when he had to deal with Netanyahu,
# [10:09.640 --> 10:15.800]  was being very obstinate and was basically rejecting all of Clinton's and treaties and
# [10:15.800 --> 10:16.800]  plans.
# [10:16.800 --> 10:20.840]  And his reporter has said, who's the fucking superpower here, you know, in frustration?
# [10:20.840 --> 10:26.880]  So this is not the first time that an American president has gotten frustrated with Netanyahu.
# [10:26.880 --> 10:30.880]  But I think people reacted quite well to that on the whole because it showed that President
# [10:30.880 --> 10:32.640]  Trump was willing to choose.
# [10:32.640 --> 10:33.640]  He cares.
# [10:33.640 --> 10:37.480]  Well, first of all, he negotiated this ceasefire, which was amazing.
# [10:37.480 --> 10:42.640]  Then what happens is that there was this deadline and it was like in a fight where they
# [10:42.640 --> 10:45.440]  ring the bell and the fighters keep slugging with each other.
# [10:45.440 --> 10:46.440]  Yeah.
# [10:46.440 --> 10:49.360]  It's like they both want to get a few extra hits in.
# [10:49.360 --> 10:52.800]  And that's what that's, yeah, they got some last looks in.
# [10:52.800 --> 10:56.000]  But President Trump negotiated the ceasefire, which was extraordinary.
# [10:56.000 --> 10:59.760]  And then he's willing to reprimand Israel for basically violating the ceasefire too,
# [10:59.760 --> 11:01.840]  which you have to do if you want to enforce it.
# [11:01.840 --> 11:03.800]  So I think that's basically what happened there.
# [11:03.800 --> 11:08.200]  Now you sacks, I'm sure the audience wants to challenge you on this.
# [11:08.200 --> 11:12.280]  You were, hey, Trump is a never getting involved in forever wars.
# [11:12.280 --> 11:15.280]  Obviously, it looks like this might not be a forever war, which would be fantastic if
# [11:15.280 --> 11:17.760]  that turns out to be the case.
# [11:17.760 --> 11:22.280]  And you were saying, hey, the reason to vote for Trump is he won't get us into another
# [11:22.280 --> 11:23.280]  war.
# [11:23.280 --> 11:24.360]  And here we go.
# [11:24.360 --> 11:30.280]  And obviously Tucker Halsey, there's a number of people who are, did not want to do this.
# [11:30.280 --> 11:31.560]  And you were one of them.
# [11:31.560 --> 11:37.400]  So how do you reconcile all of this as somebody who did not want to see us do this?
# [11:37.400 --> 11:38.400]  President Trump accomplished that.
# [11:38.400 --> 11:39.400]  We're not in a forever war.
# [11:39.400 --> 11:41.400]  We're not in a war with Iran.
# [11:41.400 --> 11:45.880]  If you look at Mark Levin today, he's apoplectic because he and people like him were advocating
# [11:45.880 --> 11:47.920]  for regime change war.
# [11:47.920 --> 11:52.160]  And they felt like this was the perfect opportunity to drag the United States into such a war.
# [11:52.160 --> 11:55.760]  And President Trump resisted that and said negotiated a ceasefire.
# [11:55.760 --> 11:59.760]  So it seems to me that he lived up to exactly his promises on this.
# [11:59.760 --> 12:04.440]  Look, I think President Trump had to thread a very difficult needle here.
# [12:04.440 --> 12:09.800]  If you look at polling, vast majority of the American population believe in two things.
# [12:09.800 --> 12:14.320]  Number one, they don't want Iran getting a nuclear weapon by like 80 something percent.
# [12:14.320 --> 12:18.440]  They also by 80 something percent don't want to get dragged into a new forever war in
# [12:18.440 --> 12:19.680]  the Middle East, right?
# [12:19.680 --> 12:23.720]  They don't want to be in a long, protracted war with Iran.
# [12:23.720 --> 12:26.440]  President Trump managed to accomplish both those objectives.
# [12:26.440 --> 12:32.200]  He took out the Iranian nuclear sites in these highly precise targeted strikes, but he
# [12:32.200 --> 12:35.480]  did not get dragged into a new Middle Eastern war.
# [12:35.480 --> 12:41.040]  And in fact, he negotiated a ceasefire and at least end to the war right now between Israel
# [12:41.040 --> 12:42.040]  and Iran.
# [12:42.040 --> 12:44.600]  I think there's very few leaders who could have threaded this needle.
# [12:44.600 --> 12:47.920]  Imagine if Kamla Harris were president, just do the counterfactual, which she have had
# [12:47.920 --> 12:54.200]  the situational awareness to realize that when the Iranian struck at our base in Qatar,
# [12:54.200 --> 12:58.680]  that it was performative, that it was telegraphed, and that it was meant to basically be for
# [12:58.680 --> 13:03.280]  domestic consumption and end the war, she might have escalated it.
# [13:03.280 --> 13:08.080]  Certainly, a lot of the Neocons who were on social media were saying, this is our chance,
# [13:08.080 --> 13:09.080]  right?
# [13:09.080 --> 13:13.800]  When the Iranians engaged in that performative hit on Qatar, they were saying, we got
# [13:13.800 --> 13:17.840]  to escalate, we got to basically bomb all of Iran now and get into a big war.
# [13:17.840 --> 13:22.000]  And Trump hit the overall awareness of the situation to avoid that.
# [13:22.000 --> 13:26.040]  And this goes back to his experience with Salamani back in the first Trump administration.
# [13:26.040 --> 13:30.080]  The Iranians did the same thing where they fired some missiles at American bases, but
# [13:30.080 --> 13:31.400]  they were telegraphed.
# [13:31.400 --> 13:33.120]  We were told in advance that they were coming.
# [13:33.120 --> 13:34.440]  They were easy to avoid.
# [13:34.440 --> 13:36.080]  No Americans got harmed.
# [13:36.080 --> 13:38.720]  And then Trump ended the conflict there.
# [13:38.720 --> 13:43.200]  And I think that a lot of presidents might have gotten sucked in to a new Middle Eastern
# [13:43.200 --> 13:44.200]  war.
# [13:44.200 --> 13:46.200]  Tremoth, let me pull you in here.
# [13:46.200 --> 13:51.800]  Obviously, little cognitive dissonance folks didn't want to go to war, but we don't want
# [13:51.800 --> 13:55.200]  WMDs in the hands of Iran.
# [13:55.200 --> 13:56.680]  How do you reconcile all of this?
# [13:56.680 --> 13:58.880]  Is the outcome make it okay?
# [13:58.880 --> 14:01.840]  In your mind, or would you rather see me not get involved in this?
# [14:01.840 --> 14:03.480]  Can I up level this slightly?
# [14:03.480 --> 14:11.240]  I think that this has been probably the most important week.
# [14:11.240 --> 14:18.600]  And I would almost say most important few months in U.S. politics in 30 or 40 years.
# [14:18.600 --> 14:21.880]  And the reason is that it starts to converge.
# [14:21.880 --> 14:25.880]  A bunch of things together that I think are really worth putting on the table.
# [14:25.880 --> 14:32.880]  So from my perspective, I think what President Trump has done is almost single-handedly bring
# [14:32.880 --> 14:37.600]  back the United States as the global superpower.
# [14:37.600 --> 14:39.920]  And I would put that in all caps.
# [14:39.920 --> 14:41.600]  So what does it mean to be a superpower?
# [14:41.600 --> 14:46.040]  I've said this several times, but just to be slightly redundant.
# [14:46.040 --> 14:51.440]  In order to be a superpower, I think you need to have three things, but they work in a hierarchy.
# [14:51.440 --> 14:54.600]  The first is that you need to have technical supremacy.
# [14:54.600 --> 15:00.600]  And then from that technological supremacy, you need to establish and project economic
# [15:00.600 --> 15:04.240]  supremacy and military supremacy.
# [15:04.240 --> 15:08.540]  So if you look at the first one, you saw a tactical demonstration of technological supremacy
# [15:08.540 --> 15:10.200]  with the B2 bombers.
# [15:10.200 --> 15:14.960]  But taking a more general step back, if you look at the largest companies in the world,
# [15:14.960 --> 15:18.640]  who are the ones that are actually driving the world forward?
# [15:18.640 --> 15:20.240]  These are all American companies.
# [15:20.240 --> 15:27.920]  I think these last few months, you've seen America firing on all cylinders technologically.
# [15:27.920 --> 15:32.200]  Economically, at the same time, you now have the stock market back at all time highs, you
# [15:32.200 --> 15:37.360]  have interest rates incredibly starting to compress even in the absence of the Federal
# [15:37.360 --> 15:39.980]  Reserve willing to act on data.
# [15:39.980 --> 15:42.880]  So you're projecting economic supremacy.
# [15:42.880 --> 15:47.400]  And then these last few weeks, frankly, have been a pretty clear-cut case of military
# [15:47.400 --> 15:48.400]  supremacy.
# [15:48.400 --> 15:53.600]  So I think what's pretty simple now is like the US is essentially telling the world our
# [15:53.600 --> 15:56.320]  words, carry weight again.
# [15:56.320 --> 15:58.760]  We're going to shape the global order.
# [15:58.760 --> 16:04.160]  Countries will now have to calibrate their actions around what the US is willing to tolerate
# [16:04.160 --> 16:06.560]  and what it isn't willing to tolerate.
# [16:06.560 --> 16:11.680]  And in the case of Iran, the President made those lines, I think, really crystal clear.
# [16:11.680 --> 16:15.480]  He warned them 100 times where the line was.
# [16:15.480 --> 16:16.680]  And he was clear.
# [16:16.680 --> 16:18.160]  You cannot build nuclear weapons.
# [16:18.160 --> 16:24.080]  And when the line was crossed, then look, I think the CNNs of the world wanted to debate
# [16:24.080 --> 16:25.400]  that the line wasn't crossed.
# [16:25.400 --> 16:28.240]  All I can tell you is I don't know because I don't have access to the intel.
# [16:28.240 --> 16:33.840]  I believe what he and Tulsi Gabbard and JD Vance and Marco Rubio and Pete Heggs are
# [16:33.840 --> 16:36.920]  the same is that they crossed the line.
# [16:36.920 --> 16:41.880]  And then he'd show that he will use decisive military force when that happens.
# [16:41.880 --> 16:43.520]  But then here's what's crazy.
# [16:43.520 --> 16:46.160]  And this is where I think you become a real superpower.
# [16:46.160 --> 16:48.680]  This is what happens after.
# [16:48.680 --> 16:54.200]  Once you cross the line, you notice that he doesn't try to humiliate or dominate Iran.
# [16:54.200 --> 16:57.640]  He tells Iran that he wants them to stabilize themselves.
# [16:57.640 --> 17:01.360]  He told them that he wants to see them trading oil with China.
# [17:01.360 --> 17:06.520]  He wants to see them improving the lives of their people because he realizes that a stable
# [17:06.520 --> 17:08.840]  Iran is a stable Middle East.
# [17:08.840 --> 17:10.960]  So I think it's really amazing.
# [17:10.960 --> 17:15.560]  And then the fact that he was able to bring Israel and Iran, who's been on the verge of
# [17:15.560 --> 17:21.560]  some kind of conflict for decades and broker a ceasefire, it's a really important moment
# [17:21.560 --> 17:22.680]  I think in American history.
# [17:22.680 --> 17:28.000]  I really do think that if you look at my little framework, it is the closest thing for
# [17:28.000 --> 17:34.840]  us to being able to say that we are truly a clear, singular, hegemon global superpower
# [17:34.840 --> 17:35.840]  again.
# [17:35.840 --> 17:36.840]  And that's really exciting.
# [17:36.840 --> 17:42.680]  Well, he definitely did provide that golden bridge for Iran to cross over to and maybe
# [17:42.680 --> 17:43.840]  move into another phase.
# [17:43.840 --> 17:47.280]  But freeberg, maybe you could still man the other side of this just for the discussion
# [17:47.280 --> 17:48.280]  here.
# [17:48.280 --> 17:50.360]  This could have gone another direction.
# [17:50.360 --> 17:53.600]  We could be sitting here and there could be terrorist attacks or sleeper cells.
# [17:53.600 --> 17:57.600]  You know, in the United States, it could turn out when we do the post-mortem here that
# [17:57.600 --> 18:02.440]  they weren't close to having a nuclear bomb and we did this and we got goaded into it.
# [18:02.440 --> 18:06.320]  So maybe obviously things have gone well to date, but things might not have.
# [18:06.320 --> 18:08.760]  So maybe you could still man the other side of this.
# [18:08.760 --> 18:11.240]  What's the argument for not having done this?
# [18:11.240 --> 18:17.160]  And what if things had gone another way, how bad could this be?
# [18:17.160 --> 18:18.960]  I don't know if this is over.
# [18:18.960 --> 18:20.840]  So, well, that's my point.
# [18:20.840 --> 18:21.840]  Yeah.
# [18:21.840 --> 18:26.520]  I mean, we're kind of in the middle of a two-year-old adventure book here.
# [18:26.520 --> 18:36.000]  And I've got to imagine that the Israelis and Netanyahu who's been pretty vocal about this
# [18:36.000 --> 18:43.000]  regime that's been shouting for decades now, death to Israel, death to the USA needs
# [18:43.000 --> 18:48.520]  to change is going to suddenly say, hey, let's take a beat and walk away from this and
# [18:48.520 --> 18:51.080]  we'll all kind of have peace in the Middle East.
# [18:51.080 --> 18:55.000]  I think we've got to expect that there's another page that's coming.
# [18:55.000 --> 18:58.360]  And I don't know if you guys heard, I don't know if it's genuine or if it's authentic
# [18:58.360 --> 18:59.360]  or not.
# [18:59.360 --> 19:05.680]  Did you hear that audio of one of the kind of Mossad or IDF people calling an IRGC commander
# [19:05.680 --> 19:09.760]  and telling him that he has 24 hours to leave Iran with his wife and child?
# [19:09.760 --> 19:10.760]  Did you guys hear that?
# [19:10.760 --> 19:11.760]  Yeah.
# [19:11.760 --> 19:12.760]  I'm not.
# [19:12.760 --> 19:13.760]  I saw it.
# [19:13.760 --> 19:14.760]  I mean, I heard it.
# [19:14.760 --> 19:16.480]  It's pretty incredible.
# [19:16.480 --> 19:22.520]  And I've got to imagine that there's going to continue to be effort to destabilize whatever
# [19:22.520 --> 19:27.200]  regime remains in Iran by Israel, Mossad.
# [19:27.200 --> 19:31.680]  And this isn't going to be kind of a quiet, peaceful transition.
# [19:31.680 --> 19:33.200]  There's going to continue to be more conflict.
# [19:33.200 --> 19:37.360]  Like whether these guys are going to be trading missiles back and forth tomorrow, I think,
# [19:37.360 --> 19:39.200]  we don't really know.
# [19:39.200 --> 19:40.960]  But this isn't over.
# [19:40.960 --> 19:44.440]  And I do think that the next set of actions is going to be critical.
# [19:44.440 --> 19:48.320]  But what I was pretty surprised by, I did not, like everyone was saying, hey, we're
# [19:48.320 --> 19:49.800]  on the brink of World War III.
# [19:49.800 --> 19:55.680]  I mean, there was some serious statesmanship that must have gone on to keep China.
# [19:55.680 --> 20:01.040]  And I have no IDF had no insight or conversations with anyone to give me any sort of proprietary
# [20:01.040 --> 20:03.040]  access to knowledge about what's gone on here.
# [20:03.040 --> 20:07.520]  And I've got to imagine there were calls to China and Russia that kept them in the loop
# [20:07.520 --> 20:11.080]  and kept them in play on how this all played out.
# [20:11.080 --> 20:14.200]  Because China and Russia, the whole fear was this was going to create this magnet in
# [20:14.200 --> 20:15.760]  the Middle East that everything was going to rush in.
# [20:15.760 --> 20:19.280]  And we're going to catalyze World War III and it didn't happen.
# [20:19.280 --> 20:25.520]  So I do think that, you know, first of all, nothing that folks predicted actually happened
# [20:25.520 --> 20:27.680]  and no one predicted what did happen.
# [20:27.680 --> 20:30.280]  So I'm not going to sit here and try and talk about it.
# [20:30.280 --> 20:32.760]  I'm not going to sit here and try and predict what happened.
# [20:32.800 --> 20:37.400]  And I will say if I'm thinking about like, you know, game theory optimal poker play,
# [20:37.400 --> 20:42.120]  I got to give credit to this president because it was completely unpredictable what was
# [20:42.120 --> 20:43.120]  coming next.
# [20:43.120 --> 20:47.120]  And I don't think that there was a really clear path in what he was going to do.
# [20:47.120 --> 20:51.080]  Just like what has happened repeatedly, everyone always slams a table and says he's
# [20:51.080 --> 20:52.080]  starting World War III.
# [20:52.080 --> 20:54.160]  He's driving economic collapse.
# [20:54.160 --> 20:55.400]  Everything's about to end.
# [20:55.400 --> 21:00.120]  And then it turns out he kind of ducks and weaves and finds his way through.
# [21:00.120 --> 21:02.400]  And everyone's like, holy shit, I didn't expect that to happen.
# [21:02.400 --> 21:04.040]  It was, it's very unpredictable.
# [21:04.040 --> 21:04.960]  It's going to happen next.
# [21:04.960 --> 21:07.360]  So I am not going to sit here and try and estimate what's going to happen next.
# [21:07.360 --> 21:11.200]  I can tell you, I don't think these railings are going to sit by quietly and allow this
# [21:11.200 --> 21:16.120]  Iranian regime to continue to go out and build up a military that's constantly shouting
# [21:16.120 --> 21:18.560]  death to Israel, death to the USA.
# [21:18.560 --> 21:21.280]  And I think that they've taken their first shot and I don't think it's their last.
# [21:21.280 --> 21:22.760]  So we'll see how this all plays out.
# [21:22.760 --> 21:23.760]  I really don't know.
# [21:23.760 --> 21:25.080]  Well, I'm sure that's right.
# [21:25.080 --> 21:27.000]  Let me just tee up one person who did get it right.
# [21:27.000 --> 21:30.960]  Here's John Mishima at the All in Summit just nine months ago.
# [21:31.680 --> 21:34.560]  Let me play this clip here and get your reaction, Saks.
# [21:34.560 --> 21:41.760]  To counter the Iranian escalation scenario, the fact is Iran does not want to war with the
# [21:41.760 --> 21:42.760]  United States.
# [21:42.760 --> 21:46.200]  And the United States does not want to war with Iran.
# [21:46.200 --> 21:51.760]  And it's the Israelis, especially Benjamin Netanyahu, who has been trying to sort of suck
# [21:51.760 --> 21:58.880]  us into a war because he wants us, the United States, to really whack Iran, weaken it
# [21:58.880 --> 22:02.960]  militarily and especially to go after its nuclear capabilities.
# [22:02.960 --> 22:07.120]  Because as you well know, they are close to the point where they can develop nuclear
# [22:07.120 --> 22:08.120]  weapons.
# [22:08.120 --> 22:14.200]  So the Israelis are the ones who want us to get involved in a big war with Iran.
# [22:14.200 --> 22:16.200]  That's the escalation flashpoint.
# [22:16.200 --> 22:22.520]  And the $64,000 question is whether you think the United States and Iran kind of colluding
# [22:22.520 --> 22:26.680]  can work together to prevent the Israelis from getting a set.
# [22:26.840 --> 22:33.560]  That question will be answered based on the next who leads the next administration.
# [22:33.560 --> 22:38.760]  Well, if you believe that it matters who leads the next, the next.
# [22:38.760 --> 22:39.760]  And there are Saks.
# [22:39.760 --> 22:44.260]  There's you laughing for this incredible insight, which is, as you were saying last year,
# [22:44.260 --> 22:47.000]  and Mishima has been saying, this was manifest.
# [22:47.000 --> 22:48.000]  That's it.
# [22:48.000 --> 22:49.760]  This was going to happen no matter who was president.
# [22:49.760 --> 22:50.760]  And here we are.
# [22:50.760 --> 22:55.000]  So your thoughts on Mishima sort of, I mean, wow, he just nailed it there.
# [22:55.000 --> 22:58.120]  And that was to your question, Friedberg, by the way, so well done to Friedberg.
# [22:58.120 --> 23:01.840]  We didn't put your question at the beginning because he went on for five or ten minutes
# [23:01.840 --> 23:02.840]  there.
# [23:02.840 --> 23:06.320]  But go ahead, it's actually a reaction to Mishima's incredible prediction.
# [23:06.320 --> 23:09.440]  That's Professor Mishima being prophetic as usual.
# [23:09.440 --> 23:11.600]  But let me go back to a point that Friedberg was making.
# [23:11.600 --> 23:14.240]  To Friedberg's point here, this is not over.
# [23:14.240 --> 23:16.400]  Iran and Israel are mortal enemies.
# [23:16.400 --> 23:17.400]  And we have a ceasefire here.
# [23:17.400 --> 23:21.520]  We have a pause in the action, but it's going to flare up again at some point.
# [23:21.520 --> 23:24.640]  The question is what US policy is going to be.
# [23:24.720 --> 23:29.040]  I think that what President Trump did over the past two weeks is make it clear that number
# [23:29.040 --> 23:34.600]  one, the United States does not want to see Iran get a nuclear bomb and that we are willing
# [23:34.600 --> 23:37.480]  to take military action to prevent that.
# [23:37.480 --> 23:42.720]  But that that action will be narrowly targeted as narrowly targeted as possible to achieve
# [23:42.720 --> 23:43.720]  that objective.
# [23:43.720 --> 23:48.320]  Number two, that the United States does not have an interest in going to war to basically
# [23:48.320 --> 23:50.760]  achieve a regime change.
# [23:50.760 --> 23:55.360]  If the people of Iran want to make Iran great again by rising up and toppling the government
# [23:55.360 --> 23:56.840]  then that's up to them.
# [23:56.840 --> 23:59.520]  Certainly I think we would welcome that.
# [23:59.520 --> 24:04.760]  But the Trump administration rejected all of the calls over the past week or so for the
# [24:04.760 --> 24:09.120]  United States to plunge into a regime change war in Iran.
# [24:09.120 --> 24:12.480]  And that's why the Neocons right now are not happy at all.
# [24:12.480 --> 24:14.320]  So that's point number two.
# [24:14.320 --> 24:18.120]  Look, I think Trump found the right balance here, which is we are going to be narrowly
# [24:18.120 --> 24:24.480]  focused on preventing a threat to the United States, which is Iran having a nuclear bomb.
# [24:24.480 --> 24:28.640]  But we're not going to go plunging into another forever war, another regime change operation.
# [24:28.640 --> 24:31.080]  We've had plenty of experience with that in the Middle East.
# [24:31.080 --> 24:32.160]  None of it worked.
# [24:32.160 --> 24:38.660]  Every time we went for a regime change it backfired, backfired in Iraq, Afghanistan, Libya, and
# [24:38.660 --> 24:39.660]  on and on.
# [24:39.660 --> 24:41.640]  So there's no reason to believe regime change would work.
# [24:41.640 --> 24:46.080]  And by the way, there's no way to get regime change in a country unless you send an American
# [24:46.080 --> 24:50.580]  GIs to basically keep that government propped up in power because it's almost certainly
# [24:50.580 --> 24:53.920]  going to be perceived as a puppet of the United States.
# [24:53.920 --> 24:59.100]  I mean, if you put, you know, raise a plovie or something, the Shah's son in power in Iran,
# [24:59.100 --> 25:02.000]  he's going to face an insurgency right away.
# [25:02.000 --> 25:05.280]  And there's no way that his government is going to stay in power without the American military
# [25:05.280 --> 25:08.720]  protecting him and keeping him in power at the end of a rifle barrel.
# [25:08.720 --> 25:13.560]  So this whole idea that you can achieve regime change without its evil twin, which is nation
# [25:13.560 --> 25:15.360]  building, is a total fantasy.
# [25:15.360 --> 25:16.920]  You can't do it.
# [25:16.920 --> 25:20.120]  You would need an American occupation going on for decades.
# [25:20.120 --> 25:24.680]  And I think that the Trump administration wisely rejected all of this giddy talk.
# [25:24.680 --> 25:31.080]  Remember in the first couple of days of that Israeli surprise attack where it was Israel
# [25:31.080 --> 25:36.120]  who hit Iran and there was all this talk about decapitation that the Iranian regime was
# [25:36.120 --> 25:37.120]  about to collapse.
# [25:37.120 --> 25:39.080]  It just needed a little bit of a push.
# [25:39.080 --> 25:40.080]  Lindsey Graham.
# [25:40.080 --> 25:41.080]  Lindsey Graham.
# [25:41.080 --> 25:45.680]  He said that was all heady talk that turned out not to be true.
# [25:45.680 --> 25:49.640]  There's no question that the Iranian regime took some damage, but they did not collapse.
# [25:49.640 --> 25:54.920]  And in fact, if you look at history, one of the things Mirasharmers pointed out is that
# [25:54.920 --> 25:57.400]  you don't get regime change just through air power alone.
# [25:57.400 --> 25:59.440]  It takes boots on the ground.
# [25:59.440 --> 26:04.280]  And most Americans are not willing to put boots on the ground in Iran to change the
# [26:04.280 --> 26:05.360]  regime there.
# [26:05.360 --> 26:09.040]  We believe that it's sufficient just to keep Iran from having a nuclear weapon.
# [26:09.040 --> 26:11.440]  That's what American policy should focus on.
# [26:11.440 --> 26:12.440]  I really felt for this.
# [26:12.440 --> 26:13.440]  What do you think?
# [26:13.440 --> 26:19.040]  Well, I really felt for this check raise from Trump who was like, yeah, no, we're not doing
# [26:19.040 --> 26:20.040]  this.
# [26:20.040 --> 26:21.040]  We're not doing this.
# [26:21.040 --> 26:22.240]  And all of a sudden he does it, right?
# [26:22.240 --> 26:23.400]  Nobody expected him to do it.
# [26:23.400 --> 26:26.720]  Everybody thought he was going to not intervene.
# [26:26.720 --> 26:33.160]  And I as a Gen X or like you, Saxon, and I guess Freeberg and Shemalt as well.
# [26:33.160 --> 26:37.920]  When I saw them building the case here in the Lindsey Graham's, you know, the hawks,
# [26:37.920 --> 26:41.280]  or reports of WMDs that were imminent.
# [26:41.280 --> 26:42.880]  Who knows if that's true?
# [26:42.880 --> 26:44.880]  These people support terrorists.
# [26:44.880 --> 26:48.040]  They're trying to assassinate the president became part of this.
# [26:48.040 --> 26:52.320]  Remember that for last time with Bush senior spreading democracy in the Middle East, the
# [26:52.320 --> 26:53.320]  regime changed stuff.
# [26:53.320 --> 26:54.720]  That may be all very nervous.
# [26:54.720 --> 26:59.120]  And I think the most important next step here is that this administration explained in
# [26:59.120 --> 27:01.640]  detail to the American people.
# [27:01.640 --> 27:04.160]  So we don't have another WMD situation.
# [27:04.160 --> 27:05.600]  Just honestly the truth.
# [27:05.600 --> 27:06.600]  Like did we hit them?
# [27:06.600 --> 27:08.320]  Did we hit some of them?
# [27:08.320 --> 27:09.320]  Was there imminent?
# [27:09.320 --> 27:10.440]  Was it sort of imminent?
# [27:10.440 --> 27:11.920]  We just need to have full disclosure here.
# [27:11.920 --> 27:16.120]  I don't like the attacking the press for a leak inside of the administration.
# [27:16.120 --> 27:19.520]  It's the administration's, you know, responsibility to not have leaks.
# [27:19.520 --> 27:25.560]  And it's the press and the opposing party whoever opposes this action to really vet this.
# [27:25.560 --> 27:27.520]  And we need that part of the democratic process.
# [27:27.520 --> 27:33.000]  I hope we don't shut that down and we just blindly follow, you know, the leader because
# [27:33.000 --> 27:35.040]  it went well because this isn't over.
# [27:35.040 --> 27:36.040]  Number one.
# [27:36.040 --> 27:37.640]  So it did go well.
# [27:37.640 --> 27:39.080]  Huge credit to Trump for that.
# [27:39.080 --> 27:44.320]  If it does go well in the ends, the war in Russia's invasion of Ukraine, like give them
# [27:44.320 --> 27:45.320]  the peace prize.
# [27:45.320 --> 27:46.840]  I'm all for it.
# [27:46.840 --> 27:47.840]  Fantastic.
# [27:47.840 --> 27:51.720]  But let's get the disclosures here and let's not blame the press for getting a leak.
# [27:51.720 --> 27:55.600]  Let's actually look at this and explain to the American people what we accomplished, what
# [27:55.600 --> 27:58.440]  didn't get accomplished and what the realistic next step is.
# [27:58.440 --> 28:03.240]  And I give them a lot of credit for telling Israel where the line is and given the golden
# [28:03.240 --> 28:06.000]  bridge to Iran.
# [28:06.000 --> 28:10.040]  They will have a revolution on their own timeline, but we should not be part of that.
# [28:10.040 --> 28:11.040]  Right.
# [28:11.040 --> 28:12.640]  That's the lesson we learned to your point, Saks.
# [28:12.640 --> 28:15.520]  We can't be the revolution in Iran.
# [28:15.520 --> 28:16.520]  They have to be revolution.
# [28:16.520 --> 28:17.520]  It's got to come from the bottom up.
# [28:17.520 --> 28:20.720]  I mean, it may also disagree with one of the things you said, which is you said you
# [28:20.720 --> 28:25.920]  were starting to get nervous about the the the stampede towards war.
# [28:25.920 --> 28:28.880]  I think you were correctly perceiving what was happening in the media.
# [28:28.880 --> 28:32.080]  I mean, and this includes Fox News, especially Fox News.
# [28:32.080 --> 28:34.120]  There was all this talk about how easy it would be.
# [28:34.120 --> 28:37.800]  There'd be a cakewalk that the government was on its last legs and it was weak that
# [28:37.800 --> 28:39.120]  it was basically almost topple.
# [28:39.120 --> 28:40.640]  We just need to push it over.
# [28:40.640 --> 28:44.560]  You're right about the WMD talk that talk about the assassination.
# [28:44.560 --> 28:50.040]  This is all like a literally like a carbon copy of the arguments that were made back in
# [28:50.040 --> 28:51.040]  2003.
# [28:51.040 --> 28:53.880]  It's the playbook to get us into the Iraq war.
# [28:53.880 --> 28:55.920]  But look, I think two things are different now.
# [28:55.920 --> 28:58.720]  Number one is President Trump is not George W. Bush.
# [28:58.720 --> 29:00.800]  I mean, that was made abundantly clear.
# [29:00.800 --> 29:05.960]  Number two is we now have alternative media that even though the mainstream media and Fox
# [29:05.960 --> 29:10.600]  News was basically acting like this was 2003, you had alternative media and you had people
# [29:10.600 --> 29:12.840]  like Tucker Carlson speaking out and Steve Bannon.
# [29:12.840 --> 29:18.520]  I have to give him credit on this and others who were pointing this out and making the case
# [29:18.520 --> 29:20.160]  that this would not go well.
# [29:20.160 --> 29:26.360]  And I do think that it's been very helpful to have those course of voices as a rebuttal.
# [29:26.360 --> 29:30.480]  You know, you correctly felt that we were being pushed into war.
# [29:30.480 --> 29:35.600]  But I think this was different now because 20 years later, people remember what happened,
# [29:35.600 --> 29:39.200]  at least enough do that they're able to make the countercase.
# [29:39.200 --> 29:44.000]  And I think that fortunately we have a decision maker in chief who also remembers and
# [29:44.000 --> 29:45.320]  listens to those arguments.
# [29:45.320 --> 29:46.320]  All right.
# [29:46.320 --> 29:48.280]  I think we've made some good progress here.
# [29:48.280 --> 29:49.280]  Let's move on in the docket.
# [29:49.280 --> 29:53.080]  We've got a lot of other topics to talk about.
# [29:53.080 --> 29:54.720]  Obviously, oil prices to mop.
# [29:54.720 --> 29:57.960]  You had talked about those in relation to this action.
# [29:57.960 --> 30:00.440]  You said, Hey, if this goes poorly, we could be looking at a hundred.
# [30:00.440 --> 30:08.040]  A barrel of oil quite interestingly while it did spike a little bit up to $74, almost
# [30:08.040 --> 30:09.640]  hit your $100.
# [30:09.640 --> 30:13.000]  Chimoff racing up from the $60 mark.
# [30:13.000 --> 30:14.200]  You know, we come back down now.
# ...
# [01:35:44.400 --> 01:35:50.160]  and you are on another side. This judge in the anthropic case, I mean, the the reasoning that he
# [01:35:50.160 --> 01:35:57.040]  gave was almost identical to what Freeberg and I were arguing a year ago. And the distinction he made
# [01:35:57.040 --> 01:36:05.760]  is between input and output. If an AI model outputs some text that is basically a ripoff of
# [01:36:05.760 --> 01:36:11.760]  someone else's copyright, then of course it's guilty of copyright violation. But in the inputs
# [01:36:11.760 --> 01:36:16.560]  or pre-training is something different. And what AI models do in pre-training is they take
# [01:36:16.560 --> 01:36:23.040]  millions of text, millions of documents and they understand the positional relationship of the
# [01:36:23.040 --> 01:36:30.000]  words and they translate that into into math into a vector space called positional encoding.
# [01:36:30.000 --> 01:36:36.480]  That is a transformation of the underlying work. And in the same way that a human can read a body
# [01:36:36.480 --> 01:36:40.800]  of works and then come up with their own point of view. That is basically what AI models are doing.
# [01:36:40.800 --> 01:36:45.920]  So if AI models violates someone's copyright by outputting something that's identical, then obviously
# [01:36:45.920 --> 01:36:50.560]  that's a violation. But if all they're doing is transforming the work, they're doing positional
# [01:36:50.560 --> 01:36:55.040]  encoding and then coming up with their own unique work product, this judge said that that is not
# [01:36:55.040 --> 01:37:00.160]  a violation of copyright. I completely agree with that. One other point, one other distinction
# [01:37:00.160 --> 01:37:05.520]  of this judge made that things are very important is the difference between pirating and copyright.
# [01:37:05.520 --> 01:37:10.240]  What the judge said is, look, you have to buy the book if you're going to basically do pre-training
# [01:37:10.480 --> 01:37:15.120]  on it. You can't rip it off. That would be high-recie, but that's different than copyright.
# [01:37:15.120 --> 01:37:19.440]  And so I agree with that too. Now, just one final point on this is-
# [01:37:19.440 --> 01:37:24.880]  How would you, Sachs, on that point, how would you propose a large language model,
# [01:37:25.600 --> 01:37:30.560]  take a million books and put it in, would they buy the physical books, scan them in if you-
# [01:37:30.560 --> 01:37:35.760]  That's by the book. So what Anthropic did is they created this large repository of books.
# [01:37:35.840 --> 01:37:39.440]  And unfortunately, some of them weren't paid for. They were pirated material.
# [01:37:39.440 --> 01:37:41.200]  And so Anthropic is-
# [01:37:41.200 --> 01:37:42.160]  Allegedly, by the way.
# [01:37:42.160 --> 01:37:46.320]  Allegedly, isn't some hot water on. Then I think there is some case that's going to move forward
# [01:37:46.320 --> 01:37:51.760]  about that. But the judge distinguished again between piracy and copyright. So the point is,
# [01:37:51.760 --> 01:37:57.440]  when Anthropic should have done, apparently, is buy each copy of the book that they put in their
# [01:37:57.440 --> 01:37:58.480]  repository. If they've done that-
# [01:37:58.480 --> 01:37:59.440]  Scan them in.
# [01:37:59.440 --> 01:38:04.640]  Scan them in. They wouldn't have had this piracy claim against them. But again, that is separate
# [01:38:04.640 --> 01:38:10.800]  from copyright. Just one final point on this is I think it's very important that we end up with
# [01:38:10.800 --> 01:38:16.160]  a sensible fair use definition, like the one the judges come up with in this Anthropic case.
# [01:38:16.160 --> 01:38:20.400]  Because otherwise, we will lose the eye race to China. The fact of the matter is China's
# [01:38:20.400 --> 01:38:25.920]  not going to care about American copyright policy. They are going to train on every scrap of
# [01:38:25.920 --> 01:38:31.200]  data that's available to them on the internet. Apparently, they use a pirated book archive called
# [01:38:31.280 --> 01:38:38.160]  LibGEN. And so, you know, they're not going to buy by copyright laws at all. And if we don't allow
# [01:38:38.160 --> 01:38:45.040]  our AI models to again have a sensible fair use definition that allows them to train, but not
# [01:38:45.040 --> 01:38:50.400]  violate an output, then we will lose to Chinese AI models because they'll have more data.
# [01:38:50.400 --> 01:38:55.280]  And the fact is that the more data that you have, the better your AI model. So I do think it's
# [01:38:55.280 --> 01:38:59.280]  very important for the US to consolidate around a fair use definition that makes sense.
# [01:38:59.280 --> 01:39:03.680]  I'm not saying that this Anthropic case will be the final word. I think there will be other cases
# [01:39:03.680 --> 01:39:08.080]  that come up with other definitions. There may be other judges that disagree. Ultimately,
# [01:39:08.080 --> 01:39:13.600]  I think this is going into the stream court. But where we need to end up is with some sort of fair
# [01:39:13.600 --> 01:39:18.560]  use definition that makes sense. Otherwise, we will lose the eye race to China. Your view, J.Kell.
# [01:39:20.000 --> 01:39:24.640]  Yeah, obviously as a content creator, I'll take the other side of this. There is a nuance between
# [01:39:24.640 --> 01:39:29.840]  training and there is a nuance between the output. I like to look at this as an opportunity. YouTube
# [01:39:29.840 --> 01:39:35.120]  really did a great job with their content ID system of navigating this. Google has the most
# [01:39:35.120 --> 01:39:40.560]  experience here with Google images and Google news. The one box where you get a little snippet
# [01:39:40.560 --> 01:39:46.160]  up top. And the output is where this is really going to favor the content holders because these will
# [01:39:46.160 --> 01:39:52.880]  be competitive products in the marketplace. The need to buy a New York Times subscription is no
# [01:39:52.880 --> 01:39:58.160]  longer necessary. You can go on to a language model and ask them to give you wire cutter as one
# [01:39:58.160 --> 01:40:04.720]  example. I like to cite what are their best picks for these air conditioners or microphones for
# [01:40:04.720 --> 01:40:08.640]  podcasting and they will give it to you. And when they started doing that, that was my main reason
# [01:40:08.640 --> 01:40:11.920]  to subscribe to the New York Times. And I no longer subscribe to it. I subscribe to Open Eye
# [01:40:11.920 --> 01:40:16.720]  because they get the same information there. These cases will be very easy to win. And so I'm
# [01:40:16.720 --> 01:40:21.680]  going to explain two things. One, how you can win this case is a content company. And then two,
# [01:40:21.680 --> 01:40:29.520]  I'm going to give how the large language models can importantly win the AI race and actually not
# [01:40:30.080 --> 01:40:34.880]  destroy the business on which they are built on. These language models have nothing without the
# [01:40:34.880 --> 01:40:40.320]  content creators and the authors of these books of which I am one. They need us. And so they should
# [01:40:40.320 --> 01:40:46.080]  want to pay us. They should want us to be compensated because that will keep us more competitive
# [01:40:46.160 --> 01:40:51.120]  than China, which will just steal it one time. So here's how you win if you're a publisher.
# [01:40:51.840 --> 01:40:58.880]  All you have to do is Disney, which is suing mid-jury right now for obvious copyright violations
# [01:40:58.880 --> 01:41:04.960]  on the output in my interpretation. All you have to do is do a Marvel me. Make yourself into a Marvel
# [01:41:04.960 --> 01:41:10.160]  character. Disney me or choose your own adventure star wars and allow consumers to pay for that
# [01:41:10.960 --> 01:41:17.120]  and any author right now that pops up a website that says subscribe to the angel book and ask
# [01:41:17.120 --> 01:41:23.680]  questions of it $10 for life, $1 per year, whatever it is, they will be able to prove damages
# [01:41:23.680 --> 01:41:29.040]  very easily. And they will be able to prove that these language models are competitive. When they
# [01:41:29.040 --> 01:41:36.960]  do that, then all of the output will need to be scrubbed or contained in some way. You can see
# [01:41:36.960 --> 01:41:43.360]  this today. If you ask Chachi PT, which is the main targets, they're making $10 billion a year
# [01:41:43.360 --> 01:41:48.480]  off of in many ways, content creators work. That's why they're the big target because they have the
# [01:41:48.480 --> 01:41:53.040]  most money. They will not let you make certain images, copyrighted images, specifically the Disney
# [01:41:53.040 --> 01:41:56.960]  ones. Go ahead and try. Go try to make a Darth Vader image and they will stop you. So they know
# [01:41:56.960 --> 01:42:01.440]  they're doing it wrong and they've already put the controls in place. You need to show that this
# [01:42:01.600 --> 01:42:07.600]  is your opportunity as a content creator. And now to my second point, SACs, which is the very easy,
# [01:42:07.600 --> 01:42:12.240]  so that's how you can prove your case and win hands down versus all language models. Put a
# [01:42:12.240 --> 01:42:18.160]  competitive product in the market you will win. Then the second piece that'll make this tenable is
# [01:42:19.280 --> 01:42:24.320]  Chachi PT is making $10 billion a year, according to reports, they should give 30% of their revenue,
# [01:42:24.320 --> 01:42:30.560]  a small amount, the minority of their revenue, to the top 1,000 newspapers, publications, podcasts,
# [01:42:30.560 --> 01:42:36.640]  books, etc. And they should do that programmatically. And then they should hope that those companies
# [01:42:36.640 --> 01:42:41.600]  double their revenue and increase their investment. And then Chachi PT and the New York Times should
# [01:42:41.600 --> 01:42:45.760]  do a deal. And I predict they will do this or with another language model that's smart enough to do
# [01:42:45.760 --> 01:42:50.560]  it where when you go to Chachi PT and you do a search from the New York Times, you say, what does the
# [01:42:50.560 --> 01:42:56.160]  New York Times say about Iran or what do they say about the wire cutters say about cameras? It should
# [01:42:56.320 --> 01:43:01.040]  say authenticate with your New York Times subscription to have access to this. And on the New York Times
# [01:43:01.040 --> 01:43:06.560]  website, they should say authenticate with Chachi PT. This would allow them to have a competitive
# [01:43:06.560 --> 01:43:13.920]  advantage versus ant-propic and apples and whoever's. And this will become a massive competitive
# [01:43:13.920 --> 01:43:18.880]  advantage for the language models, just like cable channels might or Hulu might feature Disney
# [01:43:18.960 --> 01:43:26.320]  Plus or FX or whatever stations or content it is. Whoever does this first on the other side will
# [01:43:26.320 --> 01:43:31.760]  make a tremendous amount of money because they will have access to all that data and the output.
# [01:43:31.760 --> 01:43:38.880]  So you can make your kids a t-shirt or a birthday invitation using the Star Wars characters.
# [01:43:38.880 --> 01:43:45.600]  That's the easy way for us to win as Americans by respecting content creators and paying the money
# [01:43:45.600 --> 01:43:49.440]  so they can reinvest. The amount of money we're talking about here is the minimum is for the
# [01:43:49.440 --> 01:43:54.080]  tech industry. These companies are going to be worth 30% of revenue when the company is losing tons of
# [01:43:54.080 --> 01:43:59.040]  money. Yeah, that's their problem. That's not. That's their problem. There's no legal basis for that.
# [01:43:59.680 --> 01:44:04.320]  Such a specific proposal. There's only a little basis. Well, I mean, there is the music industry.
# [01:44:04.320 --> 01:44:08.640]  If you want to play music in your restaurant, you have to pay. If you want to cover somebody's song,
# [01:44:08.640 --> 01:44:12.960]  you got to pay. If you want to perform it, you have to pay. So there is tons of precedent for it.
# [01:44:12.960 --> 01:44:18.000]  If you want to play a Disney film at your kid's birthday party, yeah, you can get away with it.
# [01:44:18.000 --> 01:44:21.840]  If you do it, you would like people to get a guarantee that Chinese models like Deep Seeker
# [01:44:21.840 --> 01:44:24.880]  better than American models because they're not going to go through any of that. So that's your
# [01:44:24.880 --> 01:44:27.600]  reason of why you get to steal because they're just going to train on. No, no, no, no, no, no, no, no.
# [01:44:27.600 --> 01:44:33.440]  I don't think it's stealing the output. I'm talking about specifically. You can't copy, no, no, no, no,
# [01:44:33.440 --> 01:44:38.000]  you can't copy the output. I fully agree there. Okay, that is what the kids in the cases about.
# [01:44:38.000 --> 01:44:42.240]  No, I'm talking about free training. I'm talking about the latter. So let's talk about the latter here.
# [01:44:42.240 --> 01:44:47.040]  I'm talking specifically on the output. No one disagrees on output. Okay. So that's the licensing
# [01:44:47.040 --> 01:44:50.720]  deal I'm talking about. Don't you think it would be worth it to give Disney a hundred million dollars
# [01:44:50.720 --> 01:44:54.960]  a year to have access to all that? I have different definitions of output. Okay.
# [01:44:55.840 --> 01:44:59.200]  I think it's reasonable to pay Disney for pre-training. And I think that they do.
# [01:45:01.120 --> 01:45:05.520]  I told you though, this like we did a licensing deal with OpenAI. We meaning, you know, beast.
# [01:45:06.560 --> 01:45:10.000]  They paid us and they're using it for pre-training. It's quite reasonable.
# [01:45:10.480 --> 01:45:15.360]  Is it the right price? We have no idea. But we did it so that we could be a part of the conversation
# [01:45:15.360 --> 01:45:21.360]  and shape how these deals get done for content creators. But SACs is right. Like if you think about like
# [01:45:21.360 --> 01:45:26.880]  what is the ultimate output, the output, if you look at how a transformer behaves,
# [01:45:27.760 --> 01:45:33.360]  it's almost it's impossible to say that it's copying the input. Just not how it works. And so
# [01:45:34.160 --> 01:45:41.440]  I don't know. It turns to math. What gets recorded is vector math on the relationship between the words.
# [01:45:42.720 --> 01:45:46.720]  This is all a very interesting check. And then somehow when you feed that into a neural net with
# [01:45:46.720 --> 01:45:51.840]  billions and billions of documents, it somehow has an understanding and produces new content.
# [01:45:51.840 --> 01:45:56.080]  And that new content is not a copyright violation. So I just think that like copyright is the
# [01:45:56.080 --> 01:46:00.160]  wrong way to look at this. This is a new technology. It's transformational. And then finally,
# [01:46:00.160 --> 01:46:04.800]  we have the national security concern. All right. So this is a topic we will monitor.
# [01:46:04.800 --> 01:46:09.760]  Thanks again for listening to the number one podcast in the world. If you want to hang out
# [01:46:09.760 --> 01:46:15.760]  with the besties in here, more prophetic interviews and discussions go to the All In Summit. Now in
# [01:46:15.760 --> 01:46:20.240]  its fourth year, September 7th tonight, the Los Angeles every year. We try to one up the last year
# [01:46:20.240 --> 01:46:28.160]  and we will do it again this year. Apply for tickets all in.com. So summit or all in.com slash yada yada yada.
# [01:46:28.160 --> 01:46:32.880]  See you next time. Besties. Love you. I love you. I gotta go. Bye.
# [01:46:58.160 --> 01:47:04.880]  I'm going to go.
# [01:47:04.880 --> 01:47:08.160]  We should all just get a room and just have one big huge or two because they're all
# [01:47:08.160 --> 01:47:11.920]  just like this like sexual tension that we just need to release somehow.

# %% [markdown]
# ### 📄 Chunk and Prepare Transcript
#
# 1. Splits the transcript into overlapping text chunks.
# 2. Stores the chunks in a Hugging Face `Dataset` for batch summarization.
#
# > Overlap ensures context is preserved between chunks.

# %%
# ----------------- Chunking and Summarizing with Dataset -----------------
overlap = 100
chunk_size = 1024
chunks = [transcript[i:i+chunk_size] for i in range(0, len(transcript), chunk_size - overlap)]

# Create dataset
# prompts = [f"Summarize this podcast segment:\n{chunk}" for chunk in chunks]
dataset = Dataset.from_dict({"text": chunks})

print(f"Processing {len(chunks)} chunks using dataset approach...")
# Out:
# Processing 117 chunks using dataset approach...

# %%
dataset[0]
# Out:
# {'text': " Did you guys see this white house video? Oh, is your white house video? I honestly think that was the funniest post by a white house ever. It was the daddy's home video. Oh. I feel like poppin' bottles to this. Come on now. Up in the club. Oh, in the VIP. Poppin' bottles. With the rainmen, let's buy two bottles of that call in tequila. That's what I got a double. That is the best. The backstory of that is that Mark Ruto is the secretary general of NATO, called Trump Daddy at the summit. Yeah, he called him daddy. Oh, okay, got weird. Rainbow, I missed it. We were just up in the club. You want to go back to the club for a second? I do. I love the club. You ready? I love the club. Poppin' some bottles with the NATO summit. We're doing it again. Come on, freeberg. Let me see you stand up, freeberg. You're soaked enough science. What club are we going to this weekend? Oh, Daddy's home. We are going to bring the club to us. I think it's called Club NATO. Sax, can you get the hot pass? You want to come to Vegas th"}

# %% [markdown]
# ### 🧠 Summarize in Batches
#
# Runs summarization on transcript chunks in batches using the Hugging Face dataset.
#
# > Improves speed and efficiency for large transcripts.

# %%
# 📦 Process the dataset in batches for summarization
processed_dataset = dataset.map(
    summarize_batch,
    batched=True,
    batch_size=8,
    desc="🔄 Summarizing chunks"
)
# Out:
# 🔄 Summarizing chunks:   0%|          | 0/117 [00:00<?, ? examples/s]
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset

# %% [markdown]
# ### 📝 Build Final Summary
#
# Joins all chunk summaries into one final summary and prints a short preview.
#
# > Creates a clean, readable summary from the full transcript.

# %%
# 🧠 Combine chunk summaries into final output (no part labels)
summaries = processed_dataset["summary"]
final_summary = "\n\n".join(s.strip() for s in summaries)

# 📤 Display result
print(f"📝 Final summary length: {len(final_summary)} characters")
print(final_summary[:100])  # Preview the first 100 characters
# Out:
# 📝 Final summary length: 34009 characters
# Kenya's president called NATO's secretary general, called Trump Daddy at the summit. "I feel like po

# %% [markdown]
# ### 💾 Save Summary with Pickle
#
# Saves the final summary and video title to a `.pkl` file for later use.
#
# > Uses Python's `pickle` to store multiple objects together.

# %%
import pickle

# Save objects
with open("/content/podcast_summary.pkl", "wb") as f:
    pickle.dump((final_summary, selected_title), f)

print("✅ Saved to podcast_summary.pkl")
# Out:
# ✅ Saved to podcast_summary.pkl

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/podcast_summary.pkl /content/drive/MyDrive/podcast_summary.pkl
